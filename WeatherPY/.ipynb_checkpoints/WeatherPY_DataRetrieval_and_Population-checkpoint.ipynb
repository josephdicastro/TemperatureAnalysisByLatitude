# %%
#import main python libraries
import pandas as pd
import numpy as np
import time

import openweathermapy.core as owm
from citipy import citipy
from pprint import pprint

#import api keys
from config import api_key

# %%
#generate random coordinates
lats = np.random.uniform(-90,90, size=2500)
lngs = np.random.uniform(-180,180, size=2500)
coordinates = zip(lats,lngs)

#create empty list to hold unique cities
unique_cities = []

#generate unique cities list
for lat_lng in coordinates:
    city_data = citipy.nearest_city(lat_lng[0], lat_lng[1])
    city_and_country = city_data.city_name + ", " + city_data.country_code
    
    if city_and_country not in unique_cities:
        unique_cities.append(city_and_country)

num_unique_cities = len(unique_cities)
print(num_unique_cities)
# Out:
# 1422

# %%
pprint(unique_cities)
# Out:
# ['yanam, in',
#  'richards bay, za',
#  'belushya guba, ru',
#  'prado, br',
#  'rikitea, pf',
#  'mataura, pf',
#  'namibe, ao',
#  'ushuaia, ar',
#  'touros, br',
#  'vao, nc',
#  'atar, mr',
#  'bunol, es',
#  'bluff, nz',
#  'aras, no',
#  'vaitupu, wf',
#  'bolungarvik, is',
#  'atuona, pf',
#  'butaritari, ki',
#  'puerto del rosario, es',
#  'cabo san lucas, mx',
#  'dikson, ru',
#  'bredasdorp, za',
#  'lockhart, us',
#  'sibolga, id',
#  'zamora, es',
#  'soyo, ao',
#  'edd, er',
#  'severo-kurilsk, ru',
#  'leningradskiy, ru',
#  'kudahuvadhoo, mv',
#  'fortuna, us',
#  'bethel, us',
#  'sentyabrskiy, ru',
#  'egvekinot, ru',
#  'hermanus, za',
#  'troitsko-pechorsk, ru',
#  'brownwood, us',
#  'nikolskoye, ru',
#  'dzhusaly, kz',
#  'lolua, tv',
#  'kodiak, us',
#  'avarua, ck',
#  'the valley, ai',
#  'cape town, za',
#  'longyearbyen, sj',
#  'kapaa, us',
#  'kavaratti, in',
#  'pisco, pe',
#  'ambodifototra, mg',
#  'shelburne, ca',
#  'mareeba, au',
#  'dharmanagar, in',
#  'hilo, us',
#  'jamestown, sh',
#  'thompson, ca',
#  'arraial do cabo, br',
#  'barentsburg, sj',
#  'mount gambier, au',
#  'punta arenas, cl',
#  'yellowknife, ca',
#  'panaba, mx',
#  'port elizabeth, za',
#  'ipeti, pa',
#  'albany, au',
#  'busselton, au',
#  'noumea, nc',
#  'saskylakh, ru',
#  'japura, br',
#  'torbay, ca',
#  'olafsvik, is',
#  'aruja, br',
#  'fairbanks, us',
#  'taolanaro, mg',
#  'toliary, mg',
#  'brae, gb',
#  'ilulissat, gl',
#  'new norfolk, au',
#  'illoqqortoormiut, gl',
#  'pevek, ru',
#  'ribeira grande, pt',
#  'khatanga, ru',
#  'tsienyane, bw',
#  'yumen, cn',
#  'bengkulu, id',
#  'talnakh, ru',
#  'naryan-mar, ru',
#  'bonavista, ca',
#  'attawapiskat, ca',
#  'klaksvik, fo',
#  'sioux lookout, ca',
#  'hithadhoo, mv',
#  'san cristobal, ec',
#  'aksarka, ru',
#  'mys shmidta, ru',
#  'ayame, ci',
#  'northam, au',
#  'khonuu, ru',
#  'hobart, au',
#  'marcona, pe',
#  'betioky, mg',
#  'aksay, kz',
#  'tuktoyaktuk, ca',
#  'tasiilaq, gl',
#  'saint-philippe, re',
#  'laguna, br',
#  'upernavik, gl',
#  'kashi, cn',
#  'saint-pierre, pm',
#  'hay river, ca',
#  'toyooka, jp',
#  'saint anthony, ca',
#  'yar-sale, ru',
#  'tura, ru',
#  'acapulco, mx',
#  'helena, us',
#  'bereda, so',
#  'wenling, cn',
#  'katsuura, jp',
#  'sitka, us',
#  'ixtapa, mx',
#  'chapais, ca',
#  'nyurba, ru',
#  'saleaula, ws',
#  'husavik, is',
#  'muskogee, us',
#  'saint-joseph, re',
#  'ancud, cl',
#  'shimoda, jp',
#  'yabassi, cm',
#  'bud, no',
#  'loa janan, id',
#  'norman wells, ca',
#  'winchester, us',
#  'ahipara, nz',
#  'castro, cl',
#  'waingapu, id',
#  'sao miguel do araguaia, br',
#  'esperance, au',
#  'birpur, in',
#  'vaini, to',
#  'san ignacio, bz',
#  'provideniya, ru',
#  'alekseyevsk, ru',
#  'te anau, nz',
#  'kailua, us',
#  'coquimbo, cl',
#  'jiddah, sa',
#  'tsihombe, mg',
#  'samarai, pg',
#  'indianola, us',
#  'amderma, ru',
#  'longido, tz',
#  'clyde river, ca',
#  'victoria, sc',
#  'salalah, om',
#  'maragogi, br',
#  'sfantu gheorghe, ro',
#  'malwan, in',
#  'teya, ru',
#  'grindavik, is',
#  'souillac, mu',
#  'jalu, ly',
#  'hokitika, nz',
#  'pangnirtung, ca',
#  'biak, id',
#  'garden city, us',
#  'kavieng, pg',
#  'east london, za',
#  'camalu, mx',
#  'luderitz, na',
#  'sawai madhopur, in',
#  'geraldton, au',
#  'guerrero negro, mx',
#  'jacqueville, ci',
#  'sanchor, in',
#  'cockburn town, tc',
#  'balkanabat, tm',
#  'samusu, ws',
#  'patacamaya, bo',
#  'mehamn, no',
#  'scarborough, tt',
#  'san jose, gt',
#  'alexandria, eg',
#  'palabuhanratu, id',
#  'banda aceh, id',
#  'chuy, uy',
#  'vanimo, pg',
#  'iracoubo, gf',
#  'gariaband, in',
#  'pangkalanbuun, id',
#  'mahebourg, mu',
#  'haines junction, ca',
#  'glenwood springs, us',
#  'praia da vitoria, pt',
#  'urengoy, ru',
#  'lompoc, us',
#  'cabedelo, br',
#  'vardo, no',
#  'port blair, in',
#  'zhigansk, ru',
#  'bah, in',
#  'ponta do sol, cv',
#  'stykkisholmur, is',
#  'katsiveli, ua',
#  'abu samrah, qa',
#  'uyutne, ua',
#  'port alfred, za',
#  'faanui, pf',
#  'verkhnevilyuysk, ru',
#  'cayenne, gf',
#  'vestmannaeyjar, is',
#  'barrow, us',
#  'sembakung, id',
#  'cabra, ph',
#  'bilma, ne',
#  'roswell, us',
#  'solsvik, no',
#  'mitsamiouli, km',
#  'akdepe, tm',
#  'batticaloa, lk',
#  'ulefoss, no',
#  'aparecida do taboado, br',
#  'kruisfontein, za',
#  'santa maria, py',
#  'peresichna, ua',
#  'inhambane, mz',
#  'weener, de',
#  'isla mujeres, mx',
#  'angoram, pg',
#  'tiksi, ru',
#  'rubtsovsk, ru',
#  'iskateley, ru',
#  'vanavara, ru',
#  'georgetown, sh',
#  'bathsheba, bb',
#  'nizhneyansk, ru',
#  'hobyo, so',
#  'verkhnyaya inta, ru',
#  'mar del plata, ar',
#  'cidreira, br',
#  'jamnah, tn',
#  'port hawkesbury, ca',
#  'sulangan, ph',
#  'mahibadhoo, mv',
#  'fort nelson, ca',
#  'tabory, ru',
#  'kapustin yar-1, ru',
#  'coihaique, cl',
#  'kampot, kh',
#  'clonmel, ie',
#  'orlik, ru',
#  'salym, ru',
#  'karasjok, no',
#  'vila franca do campo, pt',
#  'hauterive, ca',
#  'rawson, ar',
#  'garissa, ke',
#  'tumannyy, ru',
#  'muisne, ec',
#  'najran, sa',
#  'gorno-chuyskiy, ru',
#  'carnarvon, au',
#  'sept-iles, ca',
#  'artyk, ru',
#  'danielskuil, za',
#  'listvyanskiy, ru',
#  'iqaluit, ca',
#  'non sang, th',
#  'clarksburg, us',
#  'sorland, no',
#  'sampit, id',
#  'fukue, jp',
#  'san quintin, mx',
#  'hualmay, pe',
#  'san lawrenz, mt',
#  'luan, cn',
#  'san vicente, ph',
#  'saint-leu, re',
#  'suicheng, cn',
#  'paramonga, pe',
#  'kiunga, pg',
#  'asau, tv',
#  'nemuro, jp',
#  'mezocsat, hu',
#  'pallisa, ug',
#  'puerto escondido, mx',
#  'atambua, id',
#  'san lorenzo, ar',
#  'rudnogorsk, ru',
#  'dire, ml',
#  'nantucket, us',
#  'izhma, ru',
#  'kisanga, tz',
#  'tshikapa, cd',
#  'narsaq, gl',
#  'sioux falls, us',
#  'sorvag, fo',
#  'fairview, ca',
#  'pacasmayo, pe',
#  'kyle of lochalsh, gb',
#  'palu, id',
#  'tuy hoa, vn',
#  'makarov, ru',
#  'chara, ru',
#  'los llanos de aridane, es',
#  'srednekolymsk, ru',
#  'namatanai, pg',
#  'bemidji, us',
#  'puunsi, ee',
#  'airai, pw',
#  'vostok, ru',
#  'gorontalo, id',
#  'saldanha, za',
#  'vila velha, br',
#  'brewster, us',
#  'bur gabo, so',
#  'vila, vu',
#  'gigmoto, ph',
#  'bac lieu, vn',
#  'malbang, ph',
#  'lavrentiya, ru',
#  'dipalpur, pk',
#  'balingasay, ph',
#  'kikwit, cd',
#  'san patricio, mx',
#  'oranjemund, na',
#  'chokurdakh, ru',
#  'concepcion del uruguay, ar',
#  'buin, pg',
#  'olteni, ro',
#  'port hardy, ca',
#  'linxia, cn',
#  'beringovskiy, ru',
#  'quatre cocos, mu',
#  'obo, cf',
#  'denpasar, id',
#  'moerai, pf',
#  'mayo, ca',
#  'esil, kz',
#  'ilheus, br',
#  'porechye-rybnoye, ru',
#  'vitoria, es',
#  'pochutla, mx',
#  'tual, id',
#  'grand river south east, mu',
#  'calbuco, cl',
#  'deputatskiy, ru',
#  'constitucion, mx',
#  'izumo, jp',
#  'nouadhibou, mr',
#  'beyneu, kz',
#  'jasper, ca',
#  'lebu, cl',
#  'carballo, es',
#  'viedma, ar',
#  'lagoa, pt',
#  'magdagachi, ru',
#  'berbera, so',
#  'mallapuram, in',
#  'stoyba, ru',
#  'labuhan, id',
#  'aklavik, ca',
#  'nizhniy tsasuchey, ru',
#  'lorengau, pg',
#  'kilakarai, in',
#  'bandarbeyla, so',
#  'tiarei, pf',
#  'dunedin, nz',
#  'shingu, jp',
#  'yamoussoukro, ci',
#  'marondera, zw',
#  'paracuru, br',
#  'awbari, ly',
#  'sinnamary, gf',
#  'huarmey, pe',
#  'heishan, cn',
#  'hambantota, lk',
#  'uaua, br',
#  'codrington, ag',
#  'formoso do araguaia, br',
#  'dongsheng, cn',
#  'praia, cv',
#  'satitoa, ws',
#  'tomatlan, mx',
#  'sao filipe, cv',
#  'mashivka, ua',
#  'staraya poltavka, ru',
#  'utiroa, ki',
#  'eyl, so',
#  'la asuncion, ve',
#  'lata, sb',
#  'singaraja, id',
#  'syzran, ru',
#  'wanning, cn',
#  'el viso del alcor, es',
#  'poum, nc',
#  'yarim, ye',
#  'marrakesh, ma',
#  'necochea, ar',
#  'davila, ph',
#  'voyvozh, ru',
#  'camargo, mx',
#  'vung tau, vn',
#  'verdalsora, no',
#  'two rivers, us',
#  'gizo, sb',
#  'high rock, bs',
#  'sechura, pe',
#  'gardan diwal, af',
#  'udachnyy, ru',
#  'sao felix do xingu, br',
#  'labytnangi, ru',
#  'broome, au',
#  'tazovskiy, ru',
#  'verkhnetulomskiy, ru',
#  'roald, no',
#  'oyskhara, ru',
#  'wabag, pg',
#  'aripuana, br',
#  'kutum, sd',
#  'sataua, ws',
#  'ganjam, in',
#  'chengdu, cn',
#  'port lincoln, au',
#  'cesis, lv',
#  'caravelas, br',
#  'umzimvubu, za',
#  'qaanaaq, gl',
#  'prachuap khiri khan, th',
#  'moose factory, ca',
#  'lakes entrance, au',
#  'elliot lake, ca',
#  'westport, nz',
#  'san jeronimo, mx',
#  'doctor pedro p. pena, py',
#  'mandalgovi, mn',
#  'kanker, in',
#  'dandong, cn',
#  'rocha, uy',
#  'itupiranga, br',
#  'novyy urengoy, ru',
#  'coron, ph',
#  'winneba, gh',
#  'nalut, ly',
#  'cherskiy, ru',
#  'kaitangata, nz',
#  'panguipulli, cl',
#  'uige, ao',
#  'puerto quijarro, bo',
#  'mouzakion, gr',
#  'ilhabela, br',
#  'nanortalik, gl',
#  'presidencia roque saenz pena, ar',
#  'alkmaar, nl',
#  'vrangel, ru',
#  'ternate, id',
#  'tazmalt, dz',
#  'port-gentil, ga',
#  'bada, ru',
#  'jabinyanah, tn',
#  'shieli, kz',
#  'euclides da cunha, br',
#  'ponta delgada, pt',
#  'isa khel, pk',
#  'makakilo city, us',
#  'grootfontein, na',
#  'eureka, us',
#  'xihe, cn',
#  'kloulklubed, pw',
#  'shubarshi, kz',
#  'guider, cm',
#  'itarema, br',
#  'sistranda, no',
#  'kamenskoye, ru',
#  'puerto ayora, ec',
#  'evreux, fr',
#  'mao, td',
#  'san juan de los lagos, mx',
#  'hami, cn',
#  'champua, in',
#  'mogadishu, so',
#  'alyangula, au',
#  'hasaki, jp',
#  'thinadhoo, mv',
#  'sobolevo, ru',
#  'sur, om',
#  'saint-francois, gp',
#  'finschhafen, pg',
#  'itaueira, br',
#  'belaya gora, ru',
#  'roma, au',
#  'atbasar, kz',
#  'berlevag, no',
#  'batemans bay, au',
#  'senneterre, ca',
#  'hargeysa, so',
#  'petropavlovsk-kamchatskiy, ru',
#  'mezen, ru',
#  'avera, pf',
#  'alice springs, au',
#  'selfoss, is',
#  'saint-marc, ht',
#  'conceicao da barra, br',
#  'gap, fr',
#  'carutapera, br',
#  'rungata, ki',
#  'gawler, au',
#  'geraldton, ca',
#  'samalaeulu, ws',
#  'oyama, jp',
#  'burica, pa',
#  'skibbereen, ie',
#  'pacific grove, us',
#  'kondoa, tz',
#  'kurilsk, ru',
#  'kununurra, au',
#  'beloha, mg',
#  'arroyo, us',
#  'galiwinku, au',
#  'troitskoye, ru',
#  'boa vista, br',
#  'muhlacker, de',
#  'ballina, ie',
#  'vazante, br',
#  'khani, ru',
#  'ebano, mx',
#  'dalvik, is',
#  'antu, in',
#  'mount isa, au',
#  'cornelio procopio, br',
#  'cangucu, br',
#  'bilibino, ru',
#  'muncar, id',
#  'ihosy, mg',
#  'muravlenko, ru',
#  'kalga, ru',
#  'piranshahr, ir',
#  'dingle, ie',
#  'riihimaki, fi',
#  'pandan, ph',
#  'itoman, jp',
#  'mendahara, id',
#  'newport, us',
#  'imbituba, br',
#  'sao joao da barra, br',
#  'flin flon, ca',
#  'baghdad, iq',
#  'kilindoni, tz',
#  'boende, cd',
#  'taruma, br',
#  'chardara, kz',
#  'seoul, kr',
#  'kirakira, sb',
#  'carthage, us',
#  'okha, ru',
#  'cowra, au',
#  'axim, gh',
#  'tynda, ru',
#  'tupik, ru',
#  'severnyy-kospashskiy, ru',
#  'shenjiamen, cn',
#  'labutta, mm',
#  'yongan, cn',
#  'ontario, us',
#  'cordoba, ar',
#  'kawalu, id',
#  'sens, fr',
#  'olinda, br',
#  'podgornoye, ru',
#  'nuuk, gl',
#  'mount darwin, zw',
#  'bambous virieux, mu',
#  'jiwani, pk',
#  'luwuk, id',
#  'siocon, ph',
#  'ticuantepe, ni',
#  'oskarshamn, se',
#  'meyungs, pw',
#  'halalo, wf',
#  'champerico, gt',
#  'baiyin, cn',
#  'paamiut, gl',
#  'alofi, nu',
#  'lajosmizse, hu',
#  'ostrovnoy, ru',
#  'mexico, us',
#  'saint george, bm',
#  'beruwala, lk',
#  'akyab, mm',
#  'zyryanka, ru',
#  'mnogovershinnyy, ru',
#  'yulara, au',
#  'orbeni, ro',
#  'palmer, us',
#  'nguiu, au',
#  'tsiroanomandidy, mg',
#  'witu, ke',
#  'rincon, an',
#  'kuching, my',
#  'olavarria, ar',
#  'mackay, au',
#  'sikea, gr',
#  'ozoir-la-ferriere, fr',
#  'afua, br',
#  'timizart, dz',
#  'chitungwiza, zw',
#  'tocache, pe',
#  'abiy adi, et',
#  'aksu, cn',
#  'mountain home, us',
#  'abha, sa',
#  'blenheim, ca',
#  'roebourne, au',
#  'lure, fr',
#  'la serena, cl',
#  'meadow lake, ca',
#  'hue, vn',
#  'isangel, vu',
#  'linjiang, cn',
#  'tambacounda, sn',
#  'birobidzhan, ru',
#  'naze, jp',
#  'ahuimanu, us',
#  'ziro, in',
#  'padang, id',
#  'kautokeino, no',
#  'grand gaube, mu',
#  'nassau, bs',
#  'krasnyy chikoy, ru',
#  'aloleng, ph',
#  'xadani, mx',
#  'kasongo-lunda, cd',
#  'takoradi, gh',
#  'palauig, ph',
#  'majene, id',
#  'nouakchott, mr',
#  'muros, es',
#  'tezu, in',
#  'birjand, ir',
#  'santa rosalia, mx',
#  'tchamba, tg',
#  'tasbuget, kz',
#  'tautira, pf',
#  'amapa, br',
#  'ust-kut, ru',
#  'kalmunai, lk',
#  'sierre, ch',
#  'ashtian, ir',
#  'albanel, ca',
#  'primorsk, ru',
#  'calahorra, es',
#  'wamba, cd',
#  'galle, lk',
#  'ayagoz, kz',
#  'ozgon, kg',
#  'tuatapere, nz',
#  'jizan, sa',
#  'makeni, sl',
#  'chagda, ru',
#  'linqing, cn',
#  'cap malheureux, mu',
#  'andenes, no',
#  'nioro, ml',
#  'tabou, ci',
#  'miles city, us',
#  'louis trichardt, za',
#  'benidorm, es',
#  'karabulak, kz',
#  'suba, ph',
#  'silver city, us',
#  'saurimo, ao',
#  'simpang, id',
#  'santa cruz balanya, gt',
#  'potgietersrus, za',
#  'constantine, dz',
#  'zyryanovsk, kz',
#  'saint-augustin, ca',
#  'kirkland lake, ca',
#  'ust-nera, ru',
#  'wairoa, nz',
#  'ossora, ru',
#  'nakhon si thammarat, th',
#  'kahului, us',
#  'oussouye, sn',
#  'baruun-urt, mn',
#  'hirado, jp',
#  'kedainiai, lt',
#  'rodniki, ru',
#  'san luis, mx',
#  'temiscaming, ca',
#  'buaran, id',
#  'tchibanga, ga',
#  'miri, my',
#  'loandjili, cg',
#  'huilong, cn',
#  'maturin, ve',
#  'oktyabrskoye, ru',
#  'nortelandia, br',
#  'terrasini, it',
#  'camacha, pt',
#  'abu kamal, sy',
#  'nisia floresta, br',
#  'manitouwadge, ca',
#  'tobolsk, ru',
#  'bucerias, mx',
#  'killybegs, ie',
#  'leua, ao',
#  'rio gallegos, ar',
#  'beian, cn',
#  'celestun, mx',
#  'buncrana, ie',
#  'kyra, ru',
#  'vredendal, za',
#  'yakymivka, ua',
#  'kisangani, cd',
#  'coruripe, br',
#  'ziguinchor, sn',
#  'lephepe, bw',
#  'mocambique, mz',
#  'camana, pe',
#  'manokwari, id',
#  'ambulu, id',
#  'la ronge, ca',
#  'clearlake, us',
#  'pelym, ru',
#  'bajram curri, al',
#  'rodrigues alves, br',
#  'vuktyl, ru',
#  'zhucheng, cn',
#  'carnarvon, za',
#  'isabela, us',
#  'quesnel, ca',
#  'cockburn town, bs',
#  'kaeo, nz',
#  'mehran, ir',
#  'rochegda, ru',
#  'portland, au',
#  'kathmandu, np',
#  'puquio, pe',
#  'san policarpo, ph',
#  'kulhudhuffushi, mv',
#  'lidorikion, gr',
#  'tiszasuly, hu',
#  'sawakin, sd',
#  'yeniseysk, ru',
#  'chulym, ru',
#  'talcahuano, cl',
#  'lardos, gr',
#  'tlahualilo, mx',
#  'henties bay, na',
#  'kemijarvi, fi',
#  'kokopo, pg',
#  'luau, ao',
#  'tilichiki, ru',
#  'shache, cn',
#  'komsomolskiy, ru',
#  'cajamarca, pe',
#  'jacareacanga, br',
#  'dwarka, in',
#  'alpena, us',
#  'pandamatenga, bw',
#  'micheweni, tz',
#  'ingham, au',
#  'fairhaven, us',
#  'ambilobe, mg',
#  'dera ismail khan, pk',
#  'xichang, cn',
#  'lesnoy, ru',
#  'ust-kamchatsk, ru',
#  'siguiri, gn',
#  'texarkana, us',
#  'sungaipenuh, id',
#  'santa rosa, ar',
#  'blagoyevo, ru',
#  'gornopravdinsk, ru',
#  'russkaya polyana, ru',
#  'barkly west, za',
#  'alotau, pg',
#  'teluknaga, id',
#  'coahuayana, mx',
#  'manzil tamim, tn',
#  'korla, cn',
#  'buarcos, pt',
#  'tsaratanana, mg',
#  'palana, ru',
#  'port shepstone, za',
#  'kindu, cd',
#  'valparaiso, cl',
#  'traiguen, cl',
#  'makat, kz',
#  'desaguadero, pe',
#  'pangody, ru',
#  'diphu, in',
#  'oistins, bb',
#  'tirlyanskiy, ru',
#  'copacabana, bo',
#  'homer, us',
#  'kupang, id',
#  'boda, cf',
#  'wewak, pg',
#  'leticia, co',
#  'nuevitas, cu',
#  'naantali, fi',
#  'ukiah, us',
#  'nenjiang, cn',
#  'grand-santi, gf',
#  'sikasso, ml',
#  'moron, mn',
#  'sakaiminato, jp',
#  'churapcha, ru',
#  'yeppoon, au',
#  'terra nova, br',
#  'gushikawa, jp',
#  'verkhovye, ru',
#  'perur, in',
#  'kropotkin, ru',
#  'mathbaria, bd',
#  'haverhill, us',
#  'agnibilekrou, ci',
#  'luganville, vu',
#  'klaeng, th',
#  'zyryanskoye, ru',
#  'telde, es',
#  'olbia, it',
#  'tawkar, sd',
#  'agogo, gh',
#  'margate, za',
#  'januaria, br',
#  'comodoro rivadavia, ar',
#  'saryshagan, kz',
#  'ust-kuyga, ru',
#  'oktyabrskiy, ru',
#  'pokrovsk, ru',
#  'devyatka, ru',
#  'faya, td',
#  'nishihara, jp',
#  'luziania, br',
#  'yuanping, cn',
#  'san carlos de bariloche, ar',
#  'nome, us',
#  'dahra, sn',
#  'rio grande, br',
#  'waipawa, nz',
#  'cumberland, ca',
#  'trelew, ar',
#  'bayevo, ru',
#  'ambon, id',
#  'byron bay, au',
#  'kijang, id',
#  'savannah bight, hn',
#  'arman, ru',
#  'evanston, us',
#  'barbar, sd',
#  'rzhaksa, ru',
#  'dingli, mt',
#  'bull savanna, jm',
#  'ust-barguzin, ru',
#  'puerto madero, mx',
#  'ha giang, vn',
#  'hashtrud, ir',
#  'chilca, pe',
#  'zhezkazgan, kz',
#  'saint-pierre, re',
#  'pouebo, nc',
#  'guicheng, cn',
#  'vaitape, pf',
#  'along, in',
#  'natal, br',
#  'casa nova, br',
#  'tete, mz',
#  'general roca, ar',
#  'honiara, sb',
#  'kugulta, ru',
#  'terrace, ca',
#  'pontian kecil, my',
#  'belgrade, us',
#  'teguldet, ru',
#  'shubarkuduk, kz',
#  'huayucachi, pe',
#  'azimur, ma',
#  'wahran, dz',
#  'san isidro, ph',
#  'baiersbronn, de',
#  'meulaboh, id',
#  'delta, mx',
#  'pithora, in',
#  'lalitpur, in',
#  'slupsk, pl',
#  'manggar, id',
#  'san antero, co',
#  'ocotal, ni',
#  'phan rang, vn',
#  'kangaatsiaq, gl',
#  'tanggu, cn',
#  'sovetskiy, ru',
#  'hare bay, ca',
#  'liverpool, ca',
#  'raudeberg, no',
#  'metehara, et',
#  'mericleri, bg',
#  'tigzirt, dz',
#  'ketchikan, us',
#  'nizhniy baskunchak, ru',
#  'khuzdar, pk',
#  'donskoye, ru',
#  'calvinia, za',
#  'barreirinhas, br',
#  'nguruka, tz',
#  'alghero, it',
#  'turtas, ru',
#  'conakry, gn',
#  'berezovyy, ru',
#  'la reforma, mx',
#  'upata, ve',
#  'ulladulla, au',
#  'karratha, au',
#  'pizarro, co',
#  'katherine, au',
#  'inongo, cd',
#  'kazbegi, ge',
#  'susangerd, ir',
#  'tecoanapa, mx',
#  'san jose, uy',
#  'abnub, eg',
#  'veraval, in',
#  'hamilton, bm',
#  'mount pleasant, us',
#  'lasa, cn',
#  'mizan teferi, et',
#  'dumas, us',
#  'lazaro cardenas, mx',
#  'cravo norte, co',
#  'lima, pe',
#  'oyem, ga',
#  'podbrdo, ba',
#  'katangli, ru',
#  'kattivakkam, in',
#  'balaipungut, id',
#  'san ramon de la nueva oran, ar',
#  'ondjiva, ao',
#  'saint-denis, re',
#  'tha chang, th',
#  'redlands, us',
#  'glendive, us',
#  'port hueneme, us',
#  'porto nacional, br',
#  'tefe, br',
#  'cloquet, us',
#  'kishtwar, in',
#  'peristera, gr',
#  'kilmez, ru',
#  'gashua, ng',
#  'yinchuan, cn',
#  'privokzalnyy, ru',
#  'megion, ru',
#  'sarh, td',
#  'abilene, us',
#  'halifax, ca',
#  'nova olimpia, br',
#  'angangxi, cn',
#  'leninsk, ru',
#  'kalaleh, ir',
#  'ndjole, ga',
#  'xiaoweizhai, cn',
#  'ksenyevka, ru',
#  'guarapari, br',
#  'yerbogachen, ru',
#  'gat, ly',
#  'tabora, tz',
#  'kuala pilah, my',
#  'adre, td',
#  'bauchi, ng',
#  'doha, qa',
#  'taoudenni, ml',
#  'buraydah, sa',
#  'baykit, ru',
#  'viligili, mv',
#  'awjilah, ly',
#  'ekibastuz, kz',
#  'akhtubinsk, ru',
#  'marzuq, ly',
#  'dongzhen, cn',
#  'unye, tr',
#  'lincoln, us',
#  'key west, us',
#  'zolotkovo, ru',
#  'bantry, ie',
#  'aswan, eg',
#  'evensk, ru']

# %%
#API call limit
calls_per_minute = 60

#Callsets gives us the number of times we have to loop through unique_cities to process every record, 
#while not exceeding API Usage limits
callsets = int(num_unique_cities/calls_per_minute) + 1

print(callsets)
# Out:
# 24

# %%
#set callsets to 2 for debugging purposes
#callsets = 2

# %%
#settings for our Open Weather Map api calls
owm_settings = {"units": "imperial", "appid": api_key}

#Define list to log results for our OMW API Calls
api_call_log = []

#Create empty list that will track which cities from unique_cities successfully return OWM data
cities_in_owm = []

#For each callset, we will subset 60 cities from unique_cities into cities_to_process
cities_to_process = []

#Set initial indexes for subsetting into cities_to_process. We will increment by 60 each loop.
start = 0
end = 60

#start data retrieval    
begin_message = "----------------------------------\n" \
              + "Data Retrieval: Starting\n" \
              + "----------------------------------"

print(begin_message)

api_call_log.append(begin_message)

for callset in range(callsets):
    
    callset_group = "***********\n" \
                  + f"Beginning callset group: {callset}\n" \
                  + "***********"
    print(callset_group)
    
    api_call_log.append(callset_group)
    
    #get subset from unique_cities 
    cities_to_process = unique_cities[start:end]
    
    for i, city in enumerate(cities_to_process):

        try: 
            # test if city from cities_to_process is listed in open weather map. set to current_city if so.
            current_city = owm.get_current(city, **owm_settings)
            
            #pull out specific fields from current_city as a list, and then append list to cities_in_owm 
            cities_in_owm.append([current_city("id"),
                                  current_city("name"),
                                  current_city("sys.country"),
                                  current_city("coord.lat"),
                                  current_city("coord.lon"),
                                  current_city("main.temp_max"),
                                  current_city("main.humidity"),
                                  current_city("clouds.all"),
                                  current_city("wind.speed"),
                                  current_city("dt")])
            #log successful API response 
            owm_response = f"Processed Record {i} in callset group: {callset} | {city}"

        except:
            # if city from cities_to_process was NOT in open weather map, log unsuccessful API response
            owm_response = f"Skipping Record {i} in callset group: {callset} | {city} NOT FOUND"
        
        #print owm_response
        print(owm_response)
        
        #append response to api_call_log
        api_call_log.append(owm_response)
    
    #setup next set of cities to subset from unique_cities
    start = end
    end = end + 60
    
    #pause for 61 seconds to not exceed API call limits
    time.sleep(61)

#end data collection

#count cities_in_owm to get total number of successful API calls 
apicalls_succesful = len(cities_in_owm)

#subtract apicalls_succesful from num_unique_cities to get number of failed API calls
apicalls_failed = num_unique_cities - apicalls_succesful

end_message = "----------------------------------\n" \
            + "Data Retrieval: Complete\n"\
            + "----------------------------------\n"\
            + "----------------------------------\n"\
            + "Results \n"\
            + "----------------------------------\n"\
            + f"Callset groups: {callsets}\n"\
            + f"API Calls - Attempts: {num_unique_cities}\n"\
            + f"API Calls - Successful:{apicalls_succesful}\n"\
            + f"API Calls - Failed:{apicalls_failed}\n"

print(end_message)

api_call_log.append(end_message)
# Out:
# ----------------------------------
# Data Retrieval: Starting
# ----------------------------------
# ***********
# Beginning callset group: 0
# ***********
# Processed Record 0 in callset group: 0 | atuona, pf
# Skipping Record 1 in callset group: 0 | mys shmidta, ru NOT FOUND
# Processed Record 2 in callset group: 0 | trinidad, cu
# Processed Record 3 in callset group: 0 | bredasdorp, za
# Processed Record 4 in callset group: 0 | ushuaia, ar
# Processed Record 5 in callset group: 0 | castro, cl
# Processed Record 6 in callset group: 0 | haradok, by
# Processed Record 7 in callset group: 0 | port alfred, za
# Processed Record 8 in callset group: 0 | troitsko-pechorsk, ru
# Processed Record 9 in callset group: 0 | mareeba, au
# Processed Record 10 in callset group: 0 | bismarck, us
# Processed Record 11 in callset group: 0 | ribeira grande, pt
# Processed Record 12 in callset group: 0 | talnakh, ru
# Processed Record 13 in callset group: 0 | pitsunda, ge
# Processed Record 14 in callset group: 0 | punta arenas, cl
# Processed Record 15 in callset group: 0 | cogua, co
# Skipping Record 16 in callset group: 0 | barentsburg, sj NOT FOUND
# Processed Record 17 in callset group: 0 | atar, mr
# Processed Record 18 in callset group: 0 | kapaa, us
# Processed Record 19 in callset group: 0 | cape town, za
# Processed Record 20 in callset group: 0 | college, us
# Processed Record 21 in callset group: 0 | albany, au
# Processed Record 22 in callset group: 0 | rikitea, pf
# Processed Record 23 in callset group: 0 | east london, za
# Processed Record 24 in callset group: 0 | ahipara, nz
# Skipping Record 25 in callset group: 0 | illoqqortoormiut, gl NOT FOUND
# Processed Record 26 in callset group: 0 | pingyin, cn
# Processed Record 27 in callset group: 0 | hambantota, lk
# Processed Record 28 in callset group: 0 | gao, ml
# Processed Record 29 in callset group: 0 | bluff, nz
# Processed Record 30 in callset group: 0 | farah, af
# Skipping Record 31 in callset group: 0 | gurskoye, ru NOT FOUND
# Skipping Record 32 in callset group: 0 | tarudant, ma NOT FOUND
# Processed Record 33 in callset group: 0 | praia, cv
# Processed Record 34 in callset group: 0 | puerto carreno, co
# Processed Record 35 in callset group: 0 | kampene, cd
# Processed Record 36 in callset group: 0 | vaini, to
# Processed Record 37 in callset group: 0 | severo-kurilsk, ru
# Processed Record 38 in callset group: 0 | deputatskiy, ru
# Processed Record 39 in callset group: 0 | kuopio, fi
# Processed Record 40 in callset group: 0 | ola, ru
# Processed Record 41 in callset group: 0 | puerto ayora, ec
# Processed Record 42 in callset group: 0 | yarada, in
# Processed Record 43 in callset group: 0 | jumla, np
# Processed Record 44 in callset group: 0 | yellowknife, ca
# Processed Record 45 in callset group: 0 | lagoa, pt
# Processed Record 46 in callset group: 0 | lavrentiya, ru
# Processed Record 47 in callset group: 0 | fortuna, us
# Processed Record 48 in callset group: 0 | upernavik, gl
# Processed Record 49 in callset group: 0 | tilichiki, ru
# Processed Record 50 in callset group: 0 | lokosovo, ru
# Skipping Record 51 in callset group: 0 | attawapiskat, ca NOT FOUND
# Processed Record 52 in callset group: 0 | cidreira, br
# Processed Record 53 in callset group: 0 | bintulu, my
# Skipping Record 54 in callset group: 0 | taolanaro, mg NOT FOUND
# Processed Record 55 in callset group: 0 | arlit, ne
# Skipping Record 56 in callset group: 0 | saint anthony, ca NOT FOUND
# Processed Record 57 in callset group: 0 | hobart, au
# Processed Record 58 in callset group: 0 | taguisa, ph
# Skipping Record 59 in callset group: 0 | mataura, pf NOT FOUND
# ***********
# Beginning callset group: 1
# ***********
# Processed Record 0 in callset group: 1 | tres picos, mx
# Processed Record 1 in callset group: 1 | tuktoyaktuk, ca
# Skipping Record 2 in callset group: 1 | gazni, af NOT FOUND
# Processed Record 3 in callset group: 1 | barrow, us
# Processed Record 4 in callset group: 1 | chalons-en-champagne, fr
# Skipping Record 5 in callset group: 1 | codrington, ag NOT FOUND
# Processed Record 6 in callset group: 1 | la ronge, ca
# Processed Record 7 in callset group: 1 | carnarvon, au
# Processed Record 8 in callset group: 1 | hermanus, za
# Skipping Record 9 in callset group: 1 | utiroa, ki NOT FOUND
# Processed Record 10 in callset group: 1 | port elizabeth, za
# Processed Record 11 in callset group: 1 | jamestown, sh
# Processed Record 12 in callset group: 1 | vila velha, br
# Skipping Record 13 in callset group: 1 | sentyabrskiy, ru NOT FOUND
# Skipping Record 14 in callset group: 1 | tumannyy, ru NOT FOUND
# Processed Record 15 in callset group: 1 | cairns, au
# Processed Record 16 in callset group: 1 | busselton, au
# Processed Record 17 in callset group: 1 | mar del plata, ar
# Processed Record 18 in callset group: 1 | martapura, id
# Processed Record 19 in callset group: 1 | kutum, sd
# Processed Record 20 in callset group: 1 | constitucion, mx
# Processed Record 21 in callset group: 1 | wukari, ng
# Processed Record 22 in callset group: 1 | nikolskoye, ru
# Processed Record 23 in callset group: 1 | cabo san lucas, mx
# Processed Record 24 in callset group: 1 | hirado, jp
# Processed Record 25 in callset group: 1 | sangin, af
# Processed Record 26 in callset group: 1 | guerrero negro, mx
# Processed Record 27 in callset group: 1 | beringovskiy, ru
# Skipping Record 28 in callset group: 1 | avera, pf NOT FOUND
# Processed Record 29 in callset group: 1 | elliot, za
# Processed Record 30 in callset group: 1 | vilhena, br
# Skipping Record 31 in callset group: 1 | saleaula, ws NOT FOUND
# Processed Record 32 in callset group: 1 | kikwit, cd
# Skipping Record 33 in callset group: 1 | vaitupu, wf NOT FOUND
# Processed Record 34 in callset group: 1 | narsaq, gl
# Processed Record 35 in callset group: 1 | pizarro, co
# Processed Record 36 in callset group: 1 | nishihara, jp
# Processed Record 37 in callset group: 1 | iqaluit, ca
# Processed Record 38 in callset group: 1 | leningradskiy, ru
# Skipping Record 39 in callset group: 1 | anklesvar, in NOT FOUND
# Processed Record 40 in callset group: 1 | tasiilaq, gl
# Processed Record 41 in callset group: 1 | alta floresta, br
# Processed Record 42 in callset group: 1 | samarai, pg
# Processed Record 43 in callset group: 1 | lindas, no
# Processed Record 44 in callset group: 1 | los palacios, cu
# Processed Record 45 in callset group: 1 | lebu, cl
# Processed Record 46 in callset group: 1 | bethel, us
# Processed Record 47 in callset group: 1 | sitka, us
# Processed Record 48 in callset group: 1 | ban nahin, la
# Processed Record 49 in callset group: 1 | hunchun, cn
# Processed Record 50 in callset group: 1 | ilulissat, gl
# Processed Record 51 in callset group: 1 | cherskiy, ru
# Skipping Record 52 in callset group: 1 | araguacu, br NOT FOUND
# Processed Record 53 in callset group: 1 | hadrut, az
# Processed Record 54 in callset group: 1 | aklavik, ca
# Processed Record 55 in callset group: 1 | saskylakh, ru
# Processed Record 56 in callset group: 1 | portland, au
# Processed Record 57 in callset group: 1 | hasaki, jp
# Processed Record 58 in callset group: 1 | galesong, id
# Processed Record 59 in callset group: 1 | butaritari, ki
# ***********
# Beginning callset group: 2
# ***********
# Processed Record 0 in callset group: 2 | arraial do cabo, br
# Processed Record 1 in callset group: 2 | rudbar, af
# Processed Record 2 in callset group: 2 | kruisfontein, za
# Skipping Record 3 in callset group: 2 | kismayo, so NOT FOUND
# Processed Record 4 in callset group: 2 | kodiak, us
# Processed Record 5 in callset group: 2 | los llanos de aridane, es
# Skipping Record 6 in callset group: 2 | ruatoria, nz NOT FOUND
# Processed Record 7 in callset group: 2 | avarua, ck
# Processed Record 8 in callset group: 2 | sol-iletsk, ru
# Processed Record 9 in callset group: 2 | yining, cn
# Processed Record 10 in callset group: 2 | provideniya, ru
# Processed Record 11 in callset group: 2 | hatsukaichi, jp
# Processed Record 12 in callset group: 2 | chuy, uy
# Processed Record 13 in callset group: 2 | varhaug, no
# Processed Record 14 in callset group: 2 | uberlandia, br
# Processed Record 15 in callset group: 2 | naze, jp
# Skipping Record 16 in callset group: 2 | lasa, cn NOT FOUND
# Skipping Record 17 in callset group: 2 | kuche, cn NOT FOUND
# Processed Record 18 in callset group: 2 | kishi, ng
# Processed Record 19 in callset group: 2 | mahebourg, mu
# Skipping Record 20 in callset group: 2 | airai, pw NOT FOUND
# Skipping Record 21 in callset group: 2 | goderich, sl NOT FOUND
# Processed Record 22 in callset group: 2 | bastia, fr
# Processed Record 23 in callset group: 2 | navashino, ru
# Processed Record 24 in callset group: 2 | boguchany, ru
# Processed Record 25 in callset group: 2 | mahina, pf
# Skipping Record 26 in callset group: 2 | burica, pa NOT FOUND
# Processed Record 27 in callset group: 2 | hammerfest, no
# Processed Record 28 in callset group: 2 | blagoyevo, ru
# Skipping Record 29 in callset group: 2 | urumqi, cn NOT FOUND
# Processed Record 30 in callset group: 2 | linhares, br
# Processed Record 31 in callset group: 2 | bilibino, ru
# Processed Record 32 in callset group: 2 | hovd, mn
# Processed Record 33 in callset group: 2 | thompson, ca
# Processed Record 34 in callset group: 2 | nanortalik, gl
# Skipping Record 35 in callset group: 2 | asfi, ma NOT FOUND
# Processed Record 36 in callset group: 2 | mitsamiouli, km
# Processed Record 37 in callset group: 2 | evensk, ru
# Processed Record 38 in callset group: 2 | chokurdakh, ru
# Processed Record 39 in callset group: 2 | tabou, ci
# Processed Record 40 in callset group: 2 | georgetown, sh
# Processed Record 41 in callset group: 2 | khatanga, ru
# Processed Record 42 in callset group: 2 | sabang, id
# Processed Record 43 in callset group: 2 | san andres, co
# Processed Record 44 in callset group: 2 | qaanaaq, gl
# Processed Record 45 in callset group: 2 | sokolo, ml
# Processed Record 46 in callset group: 2 | mahibadhoo, mv
# Processed Record 47 in callset group: 2 | spokane, us
# Processed Record 48 in callset group: 2 | lorengau, pg
# Processed Record 49 in callset group: 2 | seoul, kr
# Processed Record 50 in callset group: 2 | tahoua, ne
# Processed Record 51 in callset group: 2 | cabra, ph
# Processed Record 52 in callset group: 2 | new norfolk, au
# Processed Record 53 in callset group: 2 | tiksi, ru
# Processed Record 54 in callset group: 2 | pevek, ru
# Processed Record 55 in callset group: 2 | salalah, om
# Processed Record 56 in callset group: 2 | sobolevo, ru
# Processed Record 57 in callset group: 2 | vytegra, ru
# Processed Record 58 in callset group: 2 | elliot lake, ca
# Processed Record 59 in callset group: 2 | torbay, ca
# ***********
# Beginning callset group: 3
# ***********
# Processed Record 0 in callset group: 3 | bambous virieux, mu
# Processed Record 1 in callset group: 3 | toumodi, ci
# Processed Record 2 in callset group: 3 | hithadhoo, mv
# Skipping Record 3 in callset group: 3 | el balyana, eg NOT FOUND
# Processed Record 4 in callset group: 3 | sindor, ru
# Processed Record 5 in callset group: 3 | kaitangata, nz
# Processed Record 6 in callset group: 3 | yichang, cn
# Processed Record 7 in callset group: 3 | ponta do sol, cv
# Skipping Record 8 in callset group: 3 | gat, ly NOT FOUND
# Processed Record 9 in callset group: 3 | metro, id
# Processed Record 10 in callset group: 3 | waynesville, us
# Processed Record 11 in callset group: 3 | faanui, pf
# Processed Record 12 in callset group: 3 | calama, cl
# Processed Record 13 in callset group: 3 | eureka, us
# Processed Record 14 in callset group: 3 | corner brook, ca
# Skipping Record 15 in callset group: 3 | yaan, cn NOT FOUND
# Processed Record 16 in callset group: 3 | victoria, sc
# Processed Record 17 in callset group: 3 | constantine, dz
# Processed Record 18 in callset group: 3 | rasova, ro
# Processed Record 19 in callset group: 3 | kawhia, nz
# Processed Record 20 in callset group: 3 | brae, gb
# Processed Record 21 in callset group: 3 | nevyansk, ru
# Processed Record 22 in callset group: 3 | vestmannaeyjar, is
# Processed Record 23 in callset group: 3 | mount gambier, au
# Processed Record 24 in callset group: 3 | nara, ml
# Processed Record 25 in callset group: 3 | eisenberg, de
# Skipping Record 26 in callset group: 3 | lolua, tv NOT FOUND
# Processed Record 27 in callset group: 3 | port hardy, ca
# Processed Record 28 in callset group: 3 | srednekolymsk, ru
# Processed Record 29 in callset group: 3 | teguldet, ru
# Processed Record 30 in callset group: 3 | meulaboh, id
# Processed Record 31 in callset group: 3 | necochea, ar
# Processed Record 32 in callset group: 3 | rybnoye, ru
# Processed Record 33 in callset group: 3 | garden city, us
# Processed Record 34 in callset group: 3 | kanungu, ug
# Processed Record 35 in callset group: 3 | muisne, ec
# Processed Record 36 in callset group: 3 | krasnaya gora, ru
# Processed Record 37 in callset group: 3 | sola, vu
# Processed Record 38 in callset group: 3 | opuwo, na
# Processed Record 39 in callset group: 3 | berlevag, no
# Processed Record 40 in callset group: 3 | grand gaube, mu
# Processed Record 41 in callset group: 3 | luderitz, na
# Processed Record 42 in callset group: 3 | mehamn, no
# Skipping Record 43 in callset group: 3 | samusu, ws NOT FOUND
# Processed Record 44 in callset group: 3 | olga, ru
# Processed Record 45 in callset group: 3 | okha, ru
# Skipping Record 46 in callset group: 3 | bossembele, cf NOT FOUND
# Processed Record 47 in callset group: 3 | stabat, id
# Processed Record 48 in callset group: 3 | hilo, us
# Processed Record 49 in callset group: 3 | dikson, ru
# Processed Record 50 in callset group: 3 | springbok, za
# Processed Record 51 in callset group: 3 | souillac, mu
# Processed Record 52 in callset group: 3 | sorland, no
# Processed Record 53 in callset group: 3 | gorgan, ir
# Processed Record 54 in callset group: 3 | young, uy
# Processed Record 55 in callset group: 3 | biak, id
# Skipping Record 56 in callset group: 3 | amderma, ru NOT FOUND
# Processed Record 57 in callset group: 3 | qaqortoq, gl
# Processed Record 58 in callset group: 3 | husavik, is
# Skipping Record 59 in callset group: 3 | umzimvubu, za NOT FOUND
# ***********
# Beginning callset group: 4
# ***********
# Processed Record 0 in callset group: 4 | santa maria, cv
# Processed Record 1 in callset group: 4 | cape canaveral, us
# Processed Record 2 in callset group: 4 | aguada de pasajeros, cu
# Processed Record 3 in callset group: 4 | dicabisagan, ph
# Processed Record 4 in callset group: 4 | kysyl-syr, ru
# Processed Record 5 in callset group: 4 | dumai, id
# Processed Record 6 in callset group: 4 | cascais, pt
# Processed Record 7 in callset group: 4 | charters towers, au
# Processed Record 8 in callset group: 4 | nantucket, us
# Processed Record 9 in callset group: 4 | saint-philippe, re
# Processed Record 10 in callset group: 4 | balaipungut, id
# Processed Record 11 in callset group: 4 | balestrand, no
# Processed Record 12 in callset group: 4 | palmer, us
# Processed Record 13 in callset group: 4 | manono, cd
# Processed Record 14 in callset group: 4 | dalby, au
# Processed Record 15 in callset group: 4 | itacoatiara, br
# Skipping Record 16 in callset group: 4 | bur gabo, so NOT FOUND
# Processed Record 17 in callset group: 4 | kirakira, sb
# Processed Record 18 in callset group: 4 | kapit, my
# Processed Record 19 in callset group: 4 | katherine, au
# Processed Record 20 in callset group: 4 | teknaf, bd
# Processed Record 21 in callset group: 4 | dubbo, au
# Processed Record 22 in callset group: 4 | kamenka, ru
# Processed Record 23 in callset group: 4 | makakilo city, us
# Processed Record 24 in callset group: 4 | assiniboia, ca
# Processed Record 25 in callset group: 4 | balikpapan, id
# Processed Record 26 in callset group: 4 | banda aceh, id
# Processed Record 27 in callset group: 4 | marrakesh, ma
# Processed Record 28 in callset group: 4 | mount isa, au
# Processed Record 29 in callset group: 4 | kavieng, pg
# Processed Record 30 in callset group: 4 | shakiso, et
# Processed Record 31 in callset group: 4 | male, mv
# Processed Record 32 in callset group: 4 | puerto leguizamo, co
# Processed Record 33 in callset group: 4 | uruacu, br
# Processed Record 34 in callset group: 4 | dunedin, nz
# Processed Record 35 in callset group: 4 | jijiga, et
# Skipping Record 36 in callset group: 4 | falealupo, ws NOT FOUND
# Processed Record 37 in callset group: 4 | smithers, ca
# Skipping Record 38 in callset group: 4 | phan rang, vn NOT FOUND
# Processed Record 39 in callset group: 4 | aksarka, ru
# Processed Record 40 in callset group: 4 | strezhevoy, ru
# Processed Record 41 in callset group: 4 | atambua, id
# Processed Record 42 in callset group: 4 | katsuura, jp
# Processed Record 43 in callset group: 4 | kiama, au
# Processed Record 44 in callset group: 4 | dakar, sn
# Processed Record 45 in callset group: 4 | waingapu, id
# Processed Record 46 in callset group: 4 | jonkoping, se
# Skipping Record 47 in callset group: 4 | paradwip, in NOT FOUND
# Processed Record 48 in callset group: 4 | sumter, us
# Processed Record 49 in callset group: 4 | touros, br
# Processed Record 50 in callset group: 4 | tapes, br
# Processed Record 51 in callset group: 4 | nyurba, ru
# Processed Record 52 in callset group: 4 | shiraoi, jp
# Processed Record 53 in callset group: 4 | iskateley, ru
# Processed Record 54 in callset group: 4 | taoudenni, ml
# Processed Record 55 in callset group: 4 | talaya, ru
# Processed Record 56 in callset group: 4 | tezu, in
# Processed Record 57 in callset group: 4 | dhidhdhoo, mv
# Processed Record 58 in callset group: 4 | coleraine, gb
# Processed Record 59 in callset group: 4 | amapa, br
# ***********
# Beginning callset group: 5
# ***********
# Processed Record 0 in callset group: 5 | lewistown, us
# Processed Record 1 in callset group: 5 | shebalino, ru
# Processed Record 2 in callset group: 5 | clyde river, ca
# Processed Record 3 in callset group: 5 | saraipali, in
# Processed Record 4 in callset group: 5 | turukhansk, ru
# Skipping Record 5 in callset group: 5 | lata, sb NOT FOUND
# Processed Record 6 in callset group: 5 | emerald, au
# Skipping Record 7 in callset group: 5 | tabiauea, ki NOT FOUND
# Processed Record 8 in callset group: 5 | aranos, na
# Processed Record 9 in callset group: 5 | sambava, mg
# Processed Record 10 in callset group: 5 | ancud, cl
# Processed Record 11 in callset group: 5 | xining, cn
# Processed Record 12 in callset group: 5 | salekhard, ru
# Processed Record 13 in callset group: 5 | saint george, bm
# Skipping Record 14 in callset group: 5 | bengkulu, id NOT FOUND
# Processed Record 15 in callset group: 5 | kahului, us
# Processed Record 16 in callset group: 5 | gamba, ga
# Processed Record 17 in callset group: 5 | geraldton, ca
# Processed Record 18 in callset group: 5 | koraput, in
# Processed Record 19 in callset group: 5 | meadow lake, ca
# Processed Record 20 in callset group: 5 | pecos, us
# Skipping Record 21 in callset group: 5 | kapoeta, sd NOT FOUND
# Processed Record 22 in callset group: 5 | lydenburg, za
# Processed Record 23 in callset group: 5 | buba, gw
# Processed Record 24 in callset group: 5 | itarema, br
# Processed Record 25 in callset group: 5 | coquimbo, cl
# Processed Record 26 in callset group: 5 | vao, nc
# Processed Record 27 in callset group: 5 | kabwe, zm
# Skipping Record 28 in callset group: 5 | galiwinku, au NOT FOUND
# Processed Record 29 in callset group: 5 | byron bay, au
# Processed Record 30 in callset group: 5 | shimoda, jp
# Processed Record 31 in callset group: 5 | bambanglipuro, id
# Processed Record 32 in callset group: 5 | kushima, jp
# Processed Record 33 in callset group: 5 | bhabua, in
# Processed Record 34 in callset group: 5 | tuy hoa, vn
# Processed Record 35 in callset group: 5 | vostok, ru
# Processed Record 36 in callset group: 5 | cayenne, gf
# Processed Record 37 in callset group: 5 | klaksvik, fo
# Processed Record 38 in callset group: 5 | port blair, in
# Processed Record 39 in callset group: 5 | rumphi, mw
# Processed Record 40 in callset group: 5 | broken hill, au
# Processed Record 41 in callset group: 5 | bayshore gardens, us
# Skipping Record 42 in callset group: 5 | grand river south east, mu NOT FOUND
# Processed Record 43 in callset group: 5 | rawson, ar
# Skipping Record 44 in callset group: 5 | rawannawi, ki NOT FOUND
# Processed Record 45 in callset group: 5 | guacimo, cr
# Processed Record 46 in callset group: 5 | yarim, ye
# Processed Record 47 in callset group: 5 | batagay-alyta, ru
# Processed Record 48 in callset group: 5 | jiamusi, cn
# Skipping Record 49 in callset group: 5 | dujuma, so NOT FOUND
# Processed Record 50 in callset group: 5 | petropavlovsk-kamchatskiy, ru
# Processed Record 51 in callset group: 5 | timmins, ca
# Processed Record 52 in callset group: 5 | sao filipe, cv
# Skipping Record 53 in callset group: 5 | jibuti, dj NOT FOUND
# Processed Record 54 in callset group: 5 | huarmey, pe
# Processed Record 55 in callset group: 5 | jizan, sa
# Processed Record 56 in callset group: 5 | vangaindrano, mg
# Processed Record 57 in callset group: 5 | madimba, tz
# Processed Record 58 in callset group: 5 | ponta delgada, pt
# Processed Record 59 in callset group: 5 | sal rei, cv
# ***********
# Beginning callset group: 6
# ***********
# Processed Record 0 in callset group: 6 | sao francisco do sul, br
# Skipping Record 1 in callset group: 6 | palabuhanratu, id NOT FOUND
# Processed Record 2 in callset group: 6 | alice, us
# Processed Record 3 in callset group: 6 | svetlogorsk, ru
# Processed Record 4 in callset group: 6 | simao, cn
# Processed Record 5 in callset group: 6 | tazovskiy, ru
# Processed Record 6 in callset group: 6 | belyy yar, ru
# Processed Record 7 in callset group: 6 | hay river, ca
# Processed Record 8 in callset group: 6 | boulder city, us
# Processed Record 9 in callset group: 6 | sur, om
# Skipping Record 10 in callset group: 6 | khani, ru NOT FOUND
# Processed Record 11 in callset group: 6 | isangel, vu
# Processed Record 12 in callset group: 6 | saint-pierre, pm
# Processed Record 13 in callset group: 6 | muros, es
# Processed Record 14 in callset group: 6 | churapcha, ru
# Processed Record 15 in callset group: 6 | pilar, ph
# Processed Record 16 in callset group: 6 | pangnirtung, ca
# Skipping Record 17 in callset group: 6 | nizhneyansk, ru NOT FOUND
# Processed Record 18 in callset group: 6 | sainte-savine, fr
# Processed Record 19 in callset group: 6 | hamilton, au
# Processed Record 20 in callset group: 6 | bat khela, pk
# Processed Record 21 in callset group: 6 | lazarev, ru
# Processed Record 22 in callset group: 6 | honningsvag, no
# Processed Record 23 in callset group: 6 | qasigiannguit, gl
# Processed Record 24 in callset group: 6 | pijijiapan, mx
# Processed Record 25 in callset group: 6 | cherrapunji, in
# Processed Record 26 in callset group: 6 | omsk, ru
# Skipping Record 27 in callset group: 6 | wulanhaote, cn NOT FOUND
# Processed Record 28 in callset group: 6 | soure, br
# Processed Record 29 in callset group: 6 | tungor, ru
# Processed Record 30 in callset group: 6 | nakhon si thammarat, th
# Processed Record 31 in callset group: 6 | taber, ca
# Processed Record 32 in callset group: 6 | fare, pf
# Processed Record 33 in callset group: 6 | whitecourt, ca
# Processed Record 34 in callset group: 6 | miraflores, co
# Processed Record 35 in callset group: 6 | half moon bay, us
# Processed Record 36 in callset group: 6 | dudinka, ru
# Skipping Record 37 in callset group: 6 | laguna, br NOT FOUND
# Processed Record 38 in callset group: 6 | riyadh, sa
# Processed Record 39 in callset group: 6 | kavaratti, in
# Processed Record 40 in callset group: 6 | nadym, ru
# Processed Record 41 in callset group: 6 | nokaneng, bw
# Processed Record 42 in callset group: 6 | rocha, uy
# Processed Record 43 in callset group: 6 | moron, mn
# Processed Record 44 in callset group: 6 | mogzon, ru
# Processed Record 45 in callset group: 6 | tiznit, ma
# Processed Record 46 in callset group: 6 | sisimiut, gl
# Processed Record 47 in callset group: 6 | fairbanks, us
# Processed Record 48 in callset group: 6 | ostrovnoy, ru
# Processed Record 49 in callset group: 6 | nazarovo, ru
# Processed Record 50 in callset group: 6 | celestun, mx
# Processed Record 51 in callset group: 6 | assemini, it
# Processed Record 52 in callset group: 6 | pombas, cv
# Skipping Record 53 in callset group: 6 | belushya guba, ru NOT FOUND
# Processed Record 54 in callset group: 6 | adrar, dz
# Skipping Record 55 in callset group: 6 | chagda, ru NOT FOUND
# Processed Record 56 in callset group: 6 | armidale, au
# Skipping Record 57 in callset group: 6 | kazalinsk, kz NOT FOUND
# Processed Record 58 in callset group: 6 | whitehorse, ca
# Processed Record 59 in callset group: 6 | solenzo, bf
# ***********
# Beginning callset group: 7
# ***********
# Skipping Record 0 in callset group: 7 | kadykchan, ru NOT FOUND
# Processed Record 1 in callset group: 7 | dubti, et
# Processed Record 2 in callset group: 7 | ulladulla, au
# Processed Record 3 in callset group: 7 | vargem grande, br
# Processed Record 4 in callset group: 7 | inhambane, mz
# Processed Record 5 in callset group: 7 | marang, my
# Processed Record 6 in callset group: 7 | matay, eg
# Processed Record 7 in callset group: 7 | geilo, no
# Processed Record 8 in callset group: 7 | langsa, id
# Skipping Record 9 in callset group: 7 | faya, td NOT FOUND
# Processed Record 10 in callset group: 7 | camacha, pt
# Processed Record 11 in callset group: 7 | baculin, ph
# Processed Record 12 in callset group: 7 | zyryanka, ru
# Processed Record 13 in callset group: 7 | sembe, cg
# Processed Record 14 in callset group: 7 | innisfail, au
# Processed Record 15 in callset group: 7 | seybaplaya, mx
# Processed Record 16 in callset group: 7 | salym, ru
# Processed Record 17 in callset group: 7 | tura, ru
# Processed Record 18 in callset group: 7 | englewood, us
# Processed Record 19 in callset group: 7 | yuanping, cn
# Skipping Record 20 in callset group: 7 | karamay, cn NOT FOUND
# Processed Record 21 in callset group: 7 | havre-saint-pierre, ca
# Processed Record 22 in callset group: 7 | lompoc, us
# Processed Record 23 in callset group: 7 | jaitaran, in
# Processed Record 24 in callset group: 7 | norman wells, ca
# Skipping Record 25 in callset group: 7 | mormugao, in NOT FOUND
# Processed Record 26 in callset group: 7 | haines junction, ca
# Skipping Record 27 in callset group: 7 | karaul, ru NOT FOUND
# Processed Record 28 in callset group: 7 | gumla, in
# Processed Record 29 in callset group: 7 | agadir, ma
# Processed Record 30 in callset group: 7 | ponta do sol, pt
# Processed Record 31 in callset group: 7 | wellington, au
# Processed Record 32 in callset group: 7 | nola, cf
# Processed Record 33 in callset group: 7 | price, us
# Processed Record 34 in callset group: 7 | kloulklubed, pw
# Processed Record 35 in callset group: 7 | preeceville, ca
# Processed Record 36 in callset group: 7 | saint-paul, re
# Processed Record 37 in callset group: 7 | awjilah, ly
# Processed Record 38 in callset group: 7 | solnechnyy, ru
# Processed Record 39 in callset group: 7 | noumea, nc
# Processed Record 40 in callset group: 7 | ossora, ru
# Processed Record 41 in callset group: 7 | boca do acre, br
# Processed Record 42 in callset group: 7 | hofn, is
# Processed Record 43 in callset group: 7 | saint-joseph, re
# Processed Record 44 in callset group: 7 | flin flon, ca
# Processed Record 45 in callset group: 7 | ixtapa, mx
# Processed Record 46 in callset group: 7 | hami, cn
# Processed Record 47 in callset group: 7 | vanavara, ru
# Processed Record 48 in callset group: 7 | high rock, bs
# Processed Record 49 in callset group: 7 | yatou, cn
# Processed Record 50 in callset group: 7 | kaeo, nz
# Processed Record 51 in callset group: 7 | machilipatnam, in
# Processed Record 52 in callset group: 7 | kroya, id
# Skipping Record 53 in callset group: 7 | riaba, gq NOT FOUND
# Processed Record 54 in callset group: 7 | sungaipenuh, id
# Processed Record 55 in callset group: 7 | challapata, bo
# Processed Record 56 in callset group: 7 | port lincoln, au
# Processed Record 57 in callset group: 7 | puerto colombia, co
# Processed Record 58 in callset group: 7 | te anau, nz
# Processed Record 59 in callset group: 7 | hit, iq
# ***********
# Beginning callset group: 8
# ***********
# Processed Record 0 in callset group: 8 | pasni, pk
# Processed Record 1 in callset group: 8 | narrabri, au
# Processed Record 2 in callset group: 8 | birjand, ir
# Processed Record 3 in callset group: 8 | ilo, pe
# Processed Record 4 in callset group: 8 | aswan, eg
# Processed Record 5 in callset group: 8 | anadyr, ru
# Processed Record 6 in callset group: 8 | northam, au
# Skipping Record 7 in callset group: 8 | vila, vu NOT FOUND
# Processed Record 8 in callset group: 8 | sao joao da barra, br
# Processed Record 9 in callset group: 8 | bubaque, gw
# Processed Record 10 in callset group: 8 | boa vista, br
# Processed Record 11 in callset group: 8 | do gonbadan, ir
# Processed Record 12 in callset group: 8 | siyabuswa, za
# Processed Record 13 in callset group: 8 | salair, ru
# Processed Record 14 in callset group: 8 | sassandra, ci
# Processed Record 15 in callset group: 8 | belaya gora, ru
# Processed Record 16 in callset group: 8 | viedma, ar
# Processed Record 17 in callset group: 8 | qixingtai, cn
# Processed Record 18 in callset group: 8 | songea, tz
# Processed Record 19 in callset group: 8 | nuuk, gl
# Processed Record 20 in callset group: 8 | izola, si
# Skipping Record 21 in callset group: 8 | sakakah, sa NOT FOUND
# Processed Record 22 in callset group: 8 | saldanha, za
# Skipping Record 23 in callset group: 8 | sahrak, af NOT FOUND
# Processed Record 24 in callset group: 8 | namatanai, pg
# Processed Record 25 in callset group: 8 | bom jardim, br
# Processed Record 26 in callset group: 8 | kuah, my
# Processed Record 27 in callset group: 8 | shu, kz
# Processed Record 28 in callset group: 8 | alofi, nu
# Processed Record 29 in callset group: 8 | cangzhou, cn
# Processed Record 30 in callset group: 8 | fremont, us
# Skipping Record 31 in callset group: 8 | barawe, so NOT FOUND
# Processed Record 32 in callset group: 8 | port augusta, au
# Processed Record 33 in callset group: 8 | lensk, ru
# Processed Record 34 in callset group: 8 | abalak, ne
# Processed Record 35 in callset group: 8 | padang, id
# Processed Record 36 in callset group: 8 | matiri, tz
# Processed Record 37 in callset group: 8 | pisco, pe
# Processed Record 38 in callset group: 8 | varena, lt
# Processed Record 39 in callset group: 8 | acajutla, sv
# Processed Record 40 in callset group: 8 | aleksandrov gay, ru
# Processed Record 41 in callset group: 8 | nhulunbuy, au
# Processed Record 42 in callset group: 8 | dukat, ru
# Processed Record 43 in callset group: 8 | manicore, br
# Processed Record 44 in callset group: 8 | alekseyevsk, ru
# Processed Record 45 in callset group: 8 | ouadda, cf
# Processed Record 46 in callset group: 8 | mehran, ir
# Processed Record 47 in callset group: 8 | worthing, gb
# Processed Record 48 in callset group: 8 | kudahuvadhoo, mv
# Processed Record 49 in callset group: 8 | konstantinovka, ru
# Processed Record 50 in callset group: 8 | cam ranh, vn
# Processed Record 51 in callset group: 8 | itoman, jp
# Processed Record 52 in callset group: 8 | villa sandino, ni
# Processed Record 53 in callset group: 8 | longyearbyen, sj
# Processed Record 54 in callset group: 8 | dayong, cn
# Processed Record 55 in callset group: 8 | arman, ru
# Skipping Record 56 in callset group: 8 | bacuit, ph NOT FOUND
# Processed Record 57 in callset group: 8 | xai-xai, mz
# Processed Record 58 in callset group: 8 | davila, ph
# Processed Record 59 in callset group: 8 | barroquinha, br
# ***********
# Beginning callset group: 9
# ***********
# Processed Record 0 in callset group: 9 | eagle pass, us
# Processed Record 1 in callset group: 9 | leshukonskoye, ru
# Processed Record 2 in callset group: 9 | methoni, gr
# Processed Record 3 in callset group: 9 | najran, sa
# Processed Record 4 in callset group: 9 | alta, no
# Skipping Record 5 in callset group: 9 | toliary, mg NOT FOUND
# Processed Record 6 in callset group: 9 | longyan, cn
# Processed Record 7 in callset group: 9 | aligudarz, ir
# Skipping Record 8 in callset group: 9 | urdzhar, kz NOT FOUND
# Processed Record 9 in callset group: 9 | illapel, cl
# Skipping Record 10 in callset group: 9 | doctor pedro p. pena, py NOT FOUND
# Processed Record 11 in callset group: 9 | san policarpo, ph
# Processed Record 12 in callset group: 9 | chipata, zm
# Skipping Record 13 in callset group: 9 | ascension, bo NOT FOUND
# Processed Record 14 in callset group: 9 | yulara, au
# Skipping Record 15 in callset group: 9 | barbar, sd NOT FOUND
# Processed Record 16 in callset group: 9 | hudson bay, ca
# Processed Record 17 in callset group: 9 | kopayhorod, ua
# Processed Record 18 in callset group: 9 | atikokan, ca
# Skipping Record 19 in callset group: 9 | chaa-khol, ru NOT FOUND
# Processed Record 20 in callset group: 9 | tizimin, mx
# Skipping Record 21 in callset group: 9 | teul, mx NOT FOUND
# Processed Record 22 in callset group: 9 | yenagoa, ng
# Processed Record 23 in callset group: 9 | kargopol, ru
# Processed Record 24 in callset group: 9 | kupang, id
# Skipping Record 25 in callset group: 9 | grand centre, ca NOT FOUND
# Processed Record 26 in callset group: 9 | tessalit, ml
# Processed Record 27 in callset group: 9 | kulhudhuffushi, mv
# Processed Record 28 in callset group: 9 | nome, us
# Processed Record 29 in callset group: 9 | gebre guracha, et
# Processed Record 30 in callset group: 9 | teya, ru
# Processed Record 31 in callset group: 9 | plettenberg bay, za
# Processed Record 32 in callset group: 9 | wattegama, lk
# Skipping Record 33 in callset group: 9 | pemangkat, id NOT FOUND
# Processed Record 34 in callset group: 9 | general roca, ar
# Processed Record 35 in callset group: 9 | puerto del rosario, es
# Processed Record 36 in callset group: 9 | hobyo, so
# Processed Record 37 in callset group: 9 | esperance, au
# Processed Record 38 in callset group: 9 | las vegas, us
# Skipping Record 39 in callset group: 9 | kuytun, cn NOT FOUND
# Processed Record 40 in callset group: 9 | zhaotong, cn
# Processed Record 41 in callset group: 9 | trincomalee, lk
# Processed Record 42 in callset group: 9 | waipawa, nz
# Processed Record 43 in callset group: 9 | ikom, ng
# Skipping Record 44 in callset group: 9 | marcona, pe NOT FOUND
# Processed Record 45 in callset group: 9 | fayaoue, nc
# Processed Record 46 in callset group: 9 | ngunguru, nz
# Processed Record 47 in callset group: 9 | baghdad, iq
# Processed Record 48 in callset group: 9 | yerofey pavlovich, ru
# Processed Record 49 in callset group: 9 | albion, mu
# Processed Record 50 in callset group: 9 | shingu, jp
# Processed Record 51 in callset group: 9 | manosque, fr
# Processed Record 52 in callset group: 9 | katobu, id
# Processed Record 53 in callset group: 9 | caconda, ao
# Processed Record 54 in callset group: 9 | sydney, au
# Processed Record 55 in callset group: 9 | gardez, af
# Processed Record 56 in callset group: 9 | leninskoye, ru
# Processed Record 57 in callset group: 9 | ilave, pe
# Processed Record 58 in callset group: 9 | kaka, tm
# Processed Record 59 in callset group: 9 | dingle, ie
# ***********
# Beginning callset group: 10
# ***********
# Processed Record 0 in callset group: 10 | vardo, no
# Processed Record 1 in callset group: 10 | westport, ie
# Skipping Record 2 in callset group: 10 | olafsvik, is NOT FOUND
# Processed Record 3 in callset group: 10 | sinnamary, gf
# Processed Record 4 in callset group: 10 | inuvik, ca
# Processed Record 5 in callset group: 10 | pahrump, us
# Skipping Record 6 in callset group: 10 | waspan, ni NOT FOUND
# Processed Record 7 in callset group: 10 | riom, fr
# Processed Record 8 in callset group: 10 | baykit, ru
# Processed Record 9 in callset group: 10 | tahe, cn
# Processed Record 10 in callset group: 10 | elizabeth city, us
# Processed Record 11 in callset group: 10 | barreiras, br
# Processed Record 12 in callset group: 10 | san cristobal, ec
# Processed Record 13 in callset group: 10 | imbituba, br
# Processed Record 14 in callset group: 10 | veraval, in
# Skipping Record 15 in callset group: 10 | lyubeshiv, ua NOT FOUND
# Processed Record 16 in callset group: 10 | madaoua, ne
# Skipping Record 17 in callset group: 10 | westpunt, an NOT FOUND
# Skipping Record 18 in callset group: 10 | kushmurun, kz NOT FOUND
# Processed Record 19 in callset group: 10 | kathmandu, np
# Processed Record 20 in callset group: 10 | hualmay, pe
# Processed Record 21 in callset group: 10 | matagami, ca
# Processed Record 22 in callset group: 10 | loreto, mx
# Processed Record 23 in callset group: 10 | praya, id
# Processed Record 24 in callset group: 10 | aqtobe, kz
# Processed Record 25 in callset group: 10 | talisay, ph
# Processed Record 26 in callset group: 10 | oranjestad, aw
# Processed Record 27 in callset group: 10 | caravelas, br
# Processed Record 28 in callset group: 10 | ibimirim, br
# Processed Record 29 in callset group: 10 | edson, ca
# Processed Record 30 in callset group: 10 | prince rupert, ca
# Processed Record 31 in callset group: 10 | tete, mz
# Processed Record 32 in callset group: 10 | oyem, ga
# Processed Record 33 in callset group: 10 | mwinilunga, zm
# Processed Record 34 in callset group: 10 | vallenar, cl
# Processed Record 35 in callset group: 10 | maryville, us
# Skipping Record 36 in callset group: 10 | bobonong, bw NOT FOUND
# Processed Record 37 in callset group: 10 | nouadhibou, mr
# Processed Record 38 in callset group: 10 | krasnyy yar, ru
# Skipping Record 39 in callset group: 10 | mahanje, tz NOT FOUND
# Processed Record 40 in callset group: 10 | kindu, cd
# Processed Record 41 in callset group: 10 | yar-sale, ru
# Processed Record 42 in callset group: 10 | sabha, ly
# Processed Record 43 in callset group: 10 | sechura, pe
# Processed Record 44 in callset group: 10 | nyagan, ru
# Processed Record 45 in callset group: 10 | vila franca do campo, pt
# Processed Record 46 in callset group: 10 | jeremie, ht
# Processed Record 47 in callset group: 10 | kuryk, kz
# Processed Record 48 in callset group: 10 | port hedland, au
# Skipping Record 49 in callset group: 10 | raga, sd NOT FOUND
# Skipping Record 50 in callset group: 10 | borlange, se NOT FOUND
# Processed Record 51 in callset group: 10 | kommunisticheskiy, ru
# Processed Record 52 in callset group: 10 | cheney, us
# Processed Record 53 in callset group: 10 | elko, us
# Skipping Record 54 in callset group: 10 | asau, tv NOT FOUND
# Processed Record 55 in callset group: 10 | yeppoon, au
# Processed Record 56 in callset group: 10 | port arthur, us
# Processed Record 57 in callset group: 10 | nicoya, cr
# Processed Record 58 in callset group: 10 | kohila, ee
# Processed Record 59 in callset group: 10 | conde, br
# ***********
# Beginning callset group: 11
# ***********
# Processed Record 0 in callset group: 11 | moussoro, td
# Processed Record 1 in callset group: 11 | cururupu, br
# Processed Record 2 in callset group: 11 | mandalgovi, mn
# Skipping Record 3 in callset group: 11 | isabela, us NOT FOUND
# Processed Record 4 in callset group: 11 | bozeman, us
# Processed Record 5 in callset group: 11 | richards bay, za
# Skipping Record 6 in callset group: 11 | requena, pe NOT FOUND
# Processed Record 7 in callset group: 11 | senanga, zm
# Skipping Record 8 in callset group: 11 | andevoranto, mg NOT FOUND
# Processed Record 9 in callset group: 11 | jaisalmer, in
# Processed Record 10 in callset group: 11 | formosa, br
# Processed Record 11 in callset group: 11 | tibati, cm
# Processed Record 12 in callset group: 11 | baruun-urt, mn
# Skipping Record 13 in callset group: 11 | odweyne, so NOT FOUND
# Processed Record 14 in callset group: 11 | ketchikan, us
# Processed Record 15 in callset group: 11 | muhos, fi
# Processed Record 16 in callset group: 11 | belmonte, br
# Processed Record 17 in callset group: 11 | madison, us
# Processed Record 18 in callset group: 11 | bathsheba, bb
# Processed Record 19 in callset group: 11 | kosh-agach, ru
# Processed Record 20 in callset group: 11 | paamiut, gl
# Processed Record 21 in callset group: 11 | pacific grove, us
# Processed Record 22 in callset group: 11 | geraldton, au
# Processed Record 23 in callset group: 11 | churachandpur, in
# Skipping Record 24 in callset group: 11 | saint-georges, gf NOT FOUND
# Processed Record 25 in callset group: 11 | porto velho, br
# Processed Record 26 in callset group: 11 | siwana, in
# Processed Record 27 in callset group: 11 | taman, ru
# Skipping Record 28 in callset group: 11 | geresk, af NOT FOUND
# Skipping Record 29 in callset group: 11 | buin, pg NOT FOUND
# Processed Record 30 in callset group: 11 | san patricio, mx
# Processed Record 31 in callset group: 11 | ambon, id
# Processed Record 32 in callset group: 11 | zhigansk, ru
# Processed Record 33 in callset group: 11 | tuatapere, nz
# Processed Record 34 in callset group: 11 | penzance, gb
# Processed Record 35 in callset group: 11 | broome, au
# Skipping Record 36 in callset group: 11 | qabis, tn NOT FOUND
# Processed Record 37 in callset group: 11 | oranjemund, na
# Processed Record 38 in callset group: 11 | bowen, au
# Processed Record 39 in callset group: 11 | khash, ir
# Processed Record 40 in callset group: 11 | los algarrobos, pa
# Processed Record 41 in callset group: 11 | lyuban, by
# Processed Record 42 in callset group: 11 | taltal, cl
# Processed Record 43 in callset group: 11 | luangwa, zm
# Processed Record 44 in callset group: 11 | porto novo, cv
# Processed Record 45 in callset group: 11 | margate, za
# Processed Record 46 in callset group: 11 | pingliang, cn
# Processed Record 47 in callset group: 11 | murgab, tm
# Processed Record 48 in callset group: 11 | biloela, au
# Processed Record 49 in callset group: 11 | pundaguitan, ph
# Processed Record 50 in callset group: 11 | roebourne, au
# Processed Record 51 in callset group: 11 | takoradi, gh
# Processed Record 52 in callset group: 11 | okhotsk, ru
# Processed Record 53 in callset group: 11 | tarata, pe
# Skipping Record 54 in callset group: 11 | marzuq, ly NOT FOUND
# Processed Record 55 in callset group: 11 | homer, us
# Skipping Record 56 in callset group: 11 | canitas, mx NOT FOUND
# Processed Record 57 in callset group: 11 | ust-maya, ru
# Processed Record 58 in callset group: 11 | moroni, km
# Processed Record 59 in callset group: 11 | the valley, ai
# ***********
# Beginning callset group: 12
# ***********
# Skipping Record 0 in callset group: 12 | kristiinankaupunki, fi NOT FOUND
# Skipping Record 1 in callset group: 12 | bargal, so NOT FOUND
# Processed Record 2 in callset group: 12 | obo, cf
# Processed Record 3 in callset group: 12 | carbondale, us
# Processed Record 4 in callset group: 12 | kumbo, cm
# Processed Record 5 in callset group: 12 | tofield, ca
# Processed Record 6 in callset group: 12 | silistea crucii, ro
# Processed Record 7 in callset group: 12 | kyra, ru
# Skipping Record 8 in callset group: 12 | mazulskiy, ru NOT FOUND
# Processed Record 9 in callset group: 12 | aldan, ru
# Processed Record 10 in callset group: 12 | valence, fr
# Skipping Record 11 in callset group: 12 | jiddah, sa NOT FOUND
# Processed Record 12 in callset group: 12 | pulandian, cn
# Processed Record 13 in callset group: 12 | sept-iles, ca
# Processed Record 14 in callset group: 12 | poum, nc
# Processed Record 15 in callset group: 12 | kaseda, jp
# Processed Record 16 in callset group: 12 | gorodishche, ru
# Skipping Record 17 in callset group: 12 | qafsah, tn NOT FOUND
# Skipping Record 18 in callset group: 12 | el alto, pe NOT FOUND
# Processed Record 19 in callset group: 12 | riohacha, co
# Processed Record 20 in callset group: 12 | foxton, nz
# Processed Record 21 in callset group: 12 | mildura, au
# Processed Record 22 in callset group: 12 | shelburne, ca
# Processed Record 23 in callset group: 12 | rastolita, ro
# Processed Record 24 in callset group: 12 | pouembout, nc
# Processed Record 25 in callset group: 12 | agucadoura, pt
# Processed Record 26 in callset group: 12 | urupes, br
# Processed Record 27 in callset group: 12 | wanning, cn
# Skipping Record 28 in callset group: 12 | tsihombe, mg NOT FOUND
# Processed Record 29 in callset group: 12 | yabrud, sy
# Processed Record 30 in callset group: 12 | orlik, ru
# Skipping Record 31 in callset group: 12 | tokzar, af NOT FOUND
# Processed Record 32 in callset group: 12 | flinders, au
# Processed Record 33 in callset group: 12 | bonavista, ca
# Processed Record 34 in callset group: 12 | luorong, cn
# Processed Record 35 in callset group: 12 | vestmanna, fo
# Skipping Record 36 in callset group: 12 | tokmak, kg NOT FOUND
# Processed Record 37 in callset group: 12 | winnetka, us
# Processed Record 38 in callset group: 12 | high level, ca
# Processed Record 39 in callset group: 12 | dauphin, ca
# Processed Record 40 in callset group: 12 | chiang klang, th
# Processed Record 41 in callset group: 12 | tocopilla, cl
# Skipping Record 42 in callset group: 12 | naftah, tn NOT FOUND
# Processed Record 43 in callset group: 12 | san rafael del sur, ni
# Processed Record 44 in callset group: 12 | taksimo, ru
# Processed Record 45 in callset group: 12 | benalla, au
# Processed Record 46 in callset group: 12 | wuwei, cn
# Processed Record 47 in callset group: 12 | aksu, cn
# Skipping Record 48 in callset group: 12 | fevralsk, ru NOT FOUND
# Processed Record 49 in callset group: 12 | sapa, ph
# Processed Record 50 in callset group: 12 | dandong, cn
# Processed Record 51 in callset group: 12 | koungou, yt
# Processed Record 52 in callset group: 12 | coihaique, cl
# Processed Record 53 in callset group: 12 | port keats, au
# Processed Record 54 in callset group: 12 | labuhan, id
# Processed Record 55 in callset group: 12 | dryden, ca
# Processed Record 56 in callset group: 12 | gongzhuling, cn
# Processed Record 57 in callset group: 12 | maningrida, au
# Processed Record 58 in callset group: 12 | douala, cm
# Processed Record 59 in callset group: 12 | eston, ca
# ***********
# Beginning callset group: 13
# ***********
# Processed Record 0 in callset group: 13 | reconquista, ar
# Skipping Record 1 in callset group: 13 | bolungarvik, is NOT FOUND
# Processed Record 2 in callset group: 13 | osterhofen, de
# Processed Record 3 in callset group: 13 | karlskrona, se
# Processed Record 4 in callset group: 13 | scarborough, gb
# Processed Record 5 in callset group: 13 | tacna, pe
# Processed Record 6 in callset group: 13 | falmouth, us
# Processed Record 7 in callset group: 13 | suclayin, ph
# Processed Record 8 in callset group: 13 | hopkinsville, us
# Processed Record 9 in callset group: 13 | uglovka, ru
# Processed Record 10 in callset group: 13 | koumac, nc
# Processed Record 11 in callset group: 13 | roseburg, us
# Processed Record 12 in callset group: 13 | berdigestyakh, ru
# Processed Record 13 in callset group: 13 | san-pedro, ci
# Processed Record 14 in callset group: 13 | villamontes, bo
# Processed Record 15 in callset group: 13 | nueva guinea, ni
# Processed Record 16 in callset group: 13 | aktau, kz
# Processed Record 17 in callset group: 13 | dombarovskiy, ru
# Processed Record 18 in callset group: 13 | yantongshan, cn
# Processed Record 19 in callset group: 13 | tarko-sale, ru
# Processed Record 20 in callset group: 13 | yumen, cn
# Processed Record 21 in callset group: 13 | linjiang, cn
# Processed Record 22 in callset group: 13 | mogadishu, so
# Processed Record 23 in callset group: 13 | lodwar, ke
# Processed Record 24 in callset group: 13 | san felipe, mx
# Processed Record 25 in callset group: 13 | panaba, mx
# Processed Record 26 in callset group: 13 | narva-joesuu, ee
# Processed Record 27 in callset group: 13 | emirdag, tr
# Processed Record 28 in callset group: 13 | boende, cd
# Processed Record 29 in callset group: 13 | port-cartier, ca
# Processed Record 30 in callset group: 13 | oksfjord, no
# Processed Record 31 in callset group: 13 | halifax, ca
# Processed Record 32 in callset group: 13 | puerto penasco, mx
# Processed Record 33 in callset group: 13 | luganville, vu
# Skipping Record 34 in callset group: 13 | mizpe ramon, il NOT FOUND
# Processed Record 35 in callset group: 13 | belomorsk, ru
# Processed Record 36 in callset group: 13 | tay ninh, vn
# Processed Record 37 in callset group: 13 | hurricane, us
# Processed Record 38 in callset group: 13 | neman, ru
# Processed Record 39 in callset group: 13 | humberto de campos, br
# Processed Record 40 in callset group: 13 | kijang, id
# Processed Record 41 in callset group: 13 | ternate, id
# Processed Record 42 in callset group: 13 | piacabucu, br
# Skipping Record 43 in callset group: 13 | bowmore, gb NOT FOUND
# Processed Record 44 in callset group: 13 | vanimo, pg
# Processed Record 45 in callset group: 13 | oktyabrskiy, ru
# Processed Record 46 in callset group: 13 | dubovskoye, ru
# Processed Record 47 in callset group: 13 | saint augustine, us
# Processed Record 48 in callset group: 13 | icod de los vinos, es
# Processed Record 49 in callset group: 13 | sarab, ir
# Skipping Record 50 in callset group: 13 | emba, kz NOT FOUND
# Processed Record 51 in callset group: 13 | socorro, us
# Processed Record 52 in callset group: 13 | fort nelson, ca
# Processed Record 53 in callset group: 13 | ridgecrest, us
# Processed Record 54 in callset group: 13 | raudeberg, no
# ...
# Processed Record 11 in callset group: 19 | svetlaya, ru
# Processed Record 12 in callset group: 19 | mayumba, ga
# Processed Record 13 in callset group: 19 | krasnoyarka, ru
# Processed Record 14 in callset group: 19 | lazo, ru
# Processed Record 15 in callset group: 19 | chapais, ca
# Processed Record 16 in callset group: 19 | palmerston, au
# Processed Record 17 in callset group: 19 | bandarbeyla, so
# Processed Record 18 in callset group: 19 | salta, ar
# Processed Record 19 in callset group: 19 | chara, ru
# Processed Record 20 in callset group: 19 | batticaloa, lk
# Processed Record 21 in callset group: 19 | chabahar, ir
# Processed Record 22 in callset group: 19 | north bend, us
# Processed Record 23 in callset group: 19 | khorixas, na
# Processed Record 24 in callset group: 19 | axim, gh
# Processed Record 25 in callset group: 19 | korla, cn
# Skipping Record 26 in callset group: 19 | satitoa, ws NOT FOUND
# Processed Record 27 in callset group: 19 | jieshi, cn
# Processed Record 28 in callset group: 19 | grand-lahou, ci
# Skipping Record 29 in callset group: 19 | qui nhon, vn NOT FOUND
# Processed Record 30 in callset group: 19 | ambilobe, mg
# Processed Record 31 in callset group: 19 | vieste, it
# Processed Record 32 in callset group: 19 | chickasha, us
# Processed Record 33 in callset group: 19 | norwich, gb
# Processed Record 34 in callset group: 19 | manokwari, id
# Skipping Record 35 in callset group: 19 | el mahalla el kubra, eg NOT FOUND
# Processed Record 36 in callset group: 19 | houma, us
# Processed Record 37 in callset group: 19 | lachi, pk
# Skipping Record 38 in callset group: 19 | skalistyy, ru NOT FOUND
# Processed Record 39 in callset group: 19 | lima, pe
# Processed Record 40 in callset group: 19 | russell, nz
# Processed Record 41 in callset group: 19 | athenry, ie
# Skipping Record 42 in callset group: 19 | kegayli, uz NOT FOUND
# Processed Record 43 in callset group: 19 | lenger, kz
# Processed Record 44 in callset group: 19 | suda, ru
# Skipping Record 45 in callset group: 19 | sim, ru NOT FOUND
# Processed Record 46 in callset group: 19 | lasem, id
# Processed Record 47 in callset group: 19 | changping, cn
# Processed Record 48 in callset group: 19 | sistranda, no
# Processed Record 49 in callset group: 19 | maketu, nz
# Processed Record 50 in callset group: 19 | hattiesburg, us
# Processed Record 51 in callset group: 19 | curillo, co
# Processed Record 52 in callset group: 19 | gboko, ng
# Processed Record 53 in callset group: 19 | bondo, cd
# Processed Record 54 in callset group: 19 | arauco, cl
# Processed Record 55 in callset group: 19 | elias fausto, br
# Processed Record 56 in callset group: 19 | den helder, nl
# Processed Record 57 in callset group: 19 | campbell river, ca
# Processed Record 58 in callset group: 19 | apomu, ng
# Processed Record 59 in callset group: 19 | soe, id
# ***********
# Beginning callset group: 20
# ***********
# Processed Record 0 in callset group: 20 | ferme-neuve, ca
# Processed Record 1 in callset group: 20 | larsnes, no
# Processed Record 2 in callset group: 20 | grindavik, is
# Skipping Record 3 in callset group: 20 | bolshoye sorokino, ru NOT FOUND
# Processed Record 4 in callset group: 20 | buzmeyin, tm
# Processed Record 5 in callset group: 20 | gisborne, nz
# Processed Record 6 in callset group: 20 | santa fe, pa
# Processed Record 7 in callset group: 20 | slave lake, ca
# Processed Record 8 in callset group: 20 | aban, ru
# Processed Record 9 in callset group: 20 | zarichne, ua
# Processed Record 10 in callset group: 20 | carman, ca
# Processed Record 11 in callset group: 20 | antsohihy, mg
# Processed Record 12 in callset group: 20 | glendive, us
# Processed Record 13 in callset group: 20 | mizdah, ly
# Processed Record 14 in callset group: 20 | kushiro, jp
# Processed Record 15 in callset group: 20 | danane, ci
# Skipping Record 16 in callset group: 20 | juifang, tw NOT FOUND
# Processed Record 17 in callset group: 20 | redmond, us
# Processed Record 18 in callset group: 20 | xinqing, cn
# Processed Record 19 in callset group: 20 | aljezur, pt
# Skipping Record 20 in callset group: 20 | kamenskoye, ru NOT FOUND
# Processed Record 21 in callset group: 20 | luau, ao
# Processed Record 22 in callset group: 20 | sibolga, id
# Processed Record 23 in callset group: 20 | tautira, pf
# Processed Record 24 in callset group: 20 | fairview, ca
# Processed Record 25 in callset group: 20 | arsikere, in
# Processed Record 26 in callset group: 20 | contamana, pe
# Processed Record 27 in callset group: 20 | urucui, br
# Processed Record 28 in callset group: 20 | fethiye, tr
# Processed Record 29 in callset group: 20 | wonthaggi, au
# Processed Record 30 in callset group: 20 | bougouni, ml
# Processed Record 31 in callset group: 20 | lively, ca
# Processed Record 32 in callset group: 20 | lamu, ke
# Processed Record 33 in callset group: 20 | nairn, gb
# Processed Record 34 in callset group: 20 | thinadhoo, mv
# Skipping Record 35 in callset group: 20 | san quintin, mx NOT FOUND
# Processed Record 36 in callset group: 20 | kyzyl-suu, kg
# Processed Record 37 in callset group: 20 | tbilisi, ge
# Processed Record 38 in callset group: 20 | akora, pk
# Processed Record 39 in callset group: 20 | bela, pk
# Processed Record 40 in callset group: 20 | vazante, br
# Processed Record 41 in callset group: 20 | tokur, ru
# Processed Record 42 in callset group: 20 | sovetskiy, ru
# Processed Record 43 in callset group: 20 | alexandria, eg
# Processed Record 44 in callset group: 20 | colares, pt
# Processed Record 45 in callset group: 20 | outjo, na
# Processed Record 46 in callset group: 20 | kieta, pg
# Processed Record 47 in callset group: 20 | owando, cg
# Processed Record 48 in callset group: 20 | goure, ne
# Processed Record 49 in callset group: 20 | dutlwe, bw
# Processed Record 50 in callset group: 20 | xuddur, so
# Skipping Record 51 in callset group: 20 | tubruq, ly NOT FOUND
# Processed Record 52 in callset group: 20 | ilfracombe, gb
# Processed Record 53 in callset group: 20 | honiara, sb
# Skipping Record 54 in callset group: 20 | one hundred mile house, ca NOT FOUND
# Processed Record 55 in callset group: 20 | talakan, ru
# Processed Record 56 in callset group: 20 | george town, ky
# Processed Record 57 in callset group: 20 | yashkul, ru
# Skipping Record 58 in callset group: 20 | krasnoselkup, ru NOT FOUND
# Processed Record 59 in callset group: 20 | nurota, uz
# ***********
# Beginning callset group: 21
# ***********
# Processed Record 0 in callset group: 21 | mao, td
# Processed Record 1 in callset group: 21 | kota belud, my
# Processed Record 2 in callset group: 21 | kandrian, pg
# Processed Record 3 in callset group: 21 | formello, it
# Skipping Record 4 in callset group: 21 | sug-aksy, ru NOT FOUND
# Processed Record 5 in callset group: 21 | winsum, nl
# Processed Record 6 in callset group: 21 | komsomolskiy, ru
# Processed Record 7 in callset group: 21 | mahajanga, mg
# Processed Record 8 in callset group: 21 | ajdabiya, ly
# Processed Record 9 in callset group: 21 | sungairaya, id
# Processed Record 10 in callset group: 21 | buala, sb
# Processed Record 11 in callset group: 21 | nizhniy kuranakh, ru
# Processed Record 12 in callset group: 21 | mirebalais, ht
# Processed Record 13 in callset group: 21 | amahai, id
# Processed Record 14 in callset group: 21 | mananjary, mg
# Processed Record 15 in callset group: 21 | olavarria, ar
# Processed Record 16 in callset group: 21 | wellington, ca
# Processed Record 17 in callset group: 21 | port bannatyne, gb
# Skipping Record 18 in callset group: 21 | cazaje, ao NOT FOUND
# Processed Record 19 in callset group: 21 | ottumwa, us
# Processed Record 20 in callset group: 21 | capitao poco, br
# Skipping Record 21 in callset group: 21 | svetlyy, ru NOT FOUND
# Processed Record 22 in callset group: 21 | pangody, ru
# Skipping Record 23 in callset group: 21 | sabla, bg NOT FOUND
# Processed Record 24 in callset group: 21 | tymovskoye, ru
# Skipping Record 25 in callset group: 21 | ascension, mx NOT FOUND
# Processed Record 26 in callset group: 21 | saint-augustin, ca
# Processed Record 27 in callset group: 21 | loandjili, cg
# Processed Record 28 in callset group: 21 | suchiapa, mx
# Processed Record 29 in callset group: 21 | pringsewu, id
# Processed Record 30 in callset group: 21 | fleurus, be
# Processed Record 31 in callset group: 21 | ilhabela, br
# Processed Record 32 in callset group: 21 | trang, th
# Processed Record 33 in callset group: 21 | sioux lookout, ca
# Skipping Record 34 in callset group: 21 | samana, do NOT FOUND
# Skipping Record 35 in callset group: 21 | lephepe, bw NOT FOUND
# Skipping Record 36 in callset group: 21 | tanjong tokong, my NOT FOUND
# Processed Record 37 in callset group: 21 | khvorostyanka, ru
# Processed Record 38 in callset group: 21 | prescott, us
# Processed Record 39 in callset group: 21 | santa maria da vitoria, br
# Processed Record 40 in callset group: 21 | barcelos, br
# Skipping Record 41 in callset group: 21 | mouzakion, gr NOT FOUND
# Processed Record 42 in callset group: 21 | denpasar, id
# Processed Record 43 in callset group: 21 | moanda, ga
# Processed Record 44 in callset group: 21 | kitimat, ca
# Processed Record 45 in callset group: 21 | porbandar, in
# Processed Record 46 in callset group: 21 | nanning, cn
# Processed Record 47 in callset group: 21 | sylvan lake, ca
# Processed Record 48 in callset group: 21 | moville, ie
# Processed Record 49 in callset group: 21 | wesselsbron, za
# Processed Record 50 in callset group: 21 | jaszladany, hu
# Processed Record 51 in callset group: 21 | daura, ng
# Processed Record 52 in callset group: 21 | aksha, ru
# Processed Record 53 in callset group: 21 | warner robins, us
# Processed Record 54 in callset group: 21 | bireun, id
# Processed Record 55 in callset group: 21 | victor harbor, au
# Processed Record 56 in callset group: 21 | leh, in
# Processed Record 57 in callset group: 21 | evreux, fr
# Processed Record 58 in callset group: 21 | san juan, us
# Processed Record 59 in callset group: 21 | port shepstone, za
# ***********
# Beginning callset group: 22
# ***********
# Processed Record 0 in callset group: 22 | mfou, cm
# Skipping Record 1 in callset group: 22 | carikar, af NOT FOUND
# Skipping Record 2 in callset group: 22 | birin, dz NOT FOUND
# Processed Record 3 in callset group: 22 | sile, tr
# Processed Record 4 in callset group: 22 | shuyskoye, ru
# Skipping Record 5 in callset group: 22 | artyk, ru NOT FOUND
# Skipping Record 6 in callset group: 22 | basyanovskiy, ru NOT FOUND
# Processed Record 7 in callset group: 22 | dakoro, ne
# Processed Record 8 in callset group: 22 | pitimbu, br
# Processed Record 9 in callset group: 22 | chiredzi, zw
# Processed Record 10 in callset group: 22 | maniitsoq, gl
# Processed Record 11 in callset group: 22 | walvis bay, na
# Processed Record 12 in callset group: 22 | xiongzhou, cn
# Processed Record 13 in callset group: 22 | itupiranga, br
# Processed Record 14 in callset group: 22 | new waterford, ca
# Processed Record 15 in callset group: 22 | merauke, id
# Processed Record 16 in callset group: 22 | kaniama, cd
# Processed Record 17 in callset group: 22 | tambongon, ph
# Processed Record 18 in callset group: 22 | nerchinskiy zavod, ru
# Processed Record 19 in callset group: 22 | ibotirama, br
# Processed Record 20 in callset group: 22 | marks, ru
# Processed Record 21 in callset group: 22 | nalut, ly
# Processed Record 22 in callset group: 22 | naron, es
# Processed Record 23 in callset group: 22 | bianzhuang, cn
# Skipping Record 24 in callset group: 22 | angra, pt NOT FOUND
# Processed Record 25 in callset group: 22 | nemuro, jp
# Processed Record 26 in callset group: 22 | marsaxlokk, mt
# Skipping Record 27 in callset group: 22 | aiyinion, gr NOT FOUND
# Processed Record 28 in callset group: 22 | balkanabat, tm
# Processed Record 29 in callset group: 22 | taunggyi, mm
# Processed Record 30 in callset group: 22 | knysna, za
# Processed Record 31 in callset group: 22 | ust-nera, ru
# Skipping Record 32 in callset group: 22 | malakal, sd NOT FOUND
# Skipping Record 33 in callset group: 22 | scottsburgh, za NOT FOUND
# Processed Record 34 in callset group: 22 | minas, uy
# Processed Record 35 in callset group: 22 | hauterive, ca
# Processed Record 36 in callset group: 22 | napier, nz
# Processed Record 37 in callset group: 22 | ipilan, ph
# Processed Record 38 in callset group: 22 | paita, pe
# Processed Record 39 in callset group: 22 | aller, es
# Skipping Record 40 in callset group: 22 | maarianhamina, fi NOT FOUND
# Skipping Record 41 in callset group: 22 | umm durman, sd NOT FOUND
# Processed Record 42 in callset group: 22 | erenhot, cn
# Processed Record 43 in callset group: 22 | alice town, bs
# Processed Record 44 in callset group: 22 | lang suan, th
# Processed Record 45 in callset group: 22 | voskresenskoye, ru
# Processed Record 46 in callset group: 22 | gurbanesti, ro
# Processed Record 47 in callset group: 22 | banjar, id
# Processed Record 48 in callset group: 22 | bonthe, sl
# Processed Record 49 in callset group: 22 | aksay, kz
# Processed Record 50 in callset group: 22 | rafraf, tn
# Processed Record 51 in callset group: 22 | hereford, us
# Processed Record 52 in callset group: 22 | manta, ec
# Processed Record 53 in callset group: 22 | indramayu, id
# Processed Record 54 in callset group: 22 | datong, cn
# Processed Record 55 in callset group: 22 | cedar city, us
# Processed Record 56 in callset group: 22 | the pas, ca
# Skipping Record 57 in callset group: 22 | taburi, ph NOT FOUND
# Processed Record 58 in callset group: 22 | kenitra, ma
# Processed Record 59 in callset group: 22 | aginskoye, ru
# ***********
# Beginning callset group: 23
# ***********
# Processed Record 0 in callset group: 23 | saba, hn
# Processed Record 1 in callset group: 23 | bow island, ca
# Skipping Record 2 in callset group: 23 | aflu, dz NOT FOUND
# Processed Record 3 in callset group: 23 | key west, us
# Processed Record 4 in callset group: 23 | dauriya, ru
# Processed Record 5 in callset group: 23 | mayor pablo lagerenza, py
# Processed Record 6 in callset group: 23 | jiaxing, cn
# Processed Record 7 in callset group: 23 | newport, us
# Processed Record 8 in callset group: 23 | jiuquan, cn
# Processed Record 9 in callset group: 23 | bela vista, br
# Processed Record 10 in callset group: 23 | west bay, ky
# Skipping Record 11 in callset group: 23 | meyungs, pw NOT FOUND
# Processed Record 12 in callset group: 23 | thessalon, ca
# Processed Record 13 in callset group: 23 | lebork, pl
# Processed Record 14 in callset group: 23 | mascota, mx
# Processed Record 15 in callset group: 23 | mondragone, it
# Processed Record 16 in callset group: 23 | syamzha, ru
# Processed Record 17 in callset group: 23 | tagcatong, ph
# Processed Record 18 in callset group: 23 | beyneu, kz
# Processed Record 19 in callset group: 23 | saint marys, us
# Skipping Record 20 in callset group: 23 | bara, sd NOT FOUND
# Processed Record 21 in callset group: 23 | matadi, cd
# Processed Record 22 in callset group: 23 | granard, ie
# Processed Record 23 in callset group: 23 | upata, ve
# Processed Record 24 in callset group: 23 | savannah bight, hn
# Processed Record 25 in callset group: 23 | zaozerne, ua
# Skipping Record 26 in callset group: 23 | pingzhuang, cn NOT FOUND
# Processed Record 27 in callset group: 23 | villaviciosa, es
# Processed Record 28 in callset group: 23 | heihe, cn
# Processed Record 29 in callset group: 23 | lakes entrance, au
# Processed Record 30 in callset group: 23 | shubarkuduk, kz
# Processed Record 31 in callset group: 23 | kosa, ru
# Processed Record 32 in callset group: 23 | nizhniy tsasuchey, ru
# Skipping Record 33 in callset group: 23 | mrirt, ma NOT FOUND
# Processed Record 34 in callset group: 23 | alto araguaia, br
# Processed Record 35 in callset group: 23 | ayagoz, kz
# Skipping Record 36 in callset group: 23 | labutta, mm NOT FOUND
# Processed Record 37 in callset group: 23 | templin, de
# Processed Record 38 in callset group: 23 | lodja, cd
# Processed Record 39 in callset group: 23 | zabid, ye
# Processed Record 40 in callset group: 23 | lazaro cardenas, mx
# Processed Record 41 in callset group: 23 | hohhot, cn
# ----------------------------------
# Data Retrieval: Complete
# ----------------------------------
# ----------------------------------
# Results
# ----------------------------------
# Callset groups: 24
# API Calls - Attempts: 1422
# API Calls - Successful:1244
# API Calls - Failed:178

# %%
cities_df = pd.DataFrame(cities_in_owm, columns=["CityID","Name","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed (mph)","Date_Time"])

# %%
cities_df
# Out:
#        CityID             Name Country    Lat     Lng  Max Temp  Humdity  \
# 0     4020109           Atuona      PF  -9.80 -139.03     80.02       73
# 1     3534915         Trinidad      CU  21.81  -79.98     73.40      100
# 2     1015776       Bredasdorp      ZA -34.53   20.04     62.60       93
# 3     3833367          Ushuaia      AR -54.81  -68.31     42.80       87
# 4     3896218           Castro      CL -42.48  -73.76     50.00       93
# ...       ...              ...     ...    ...     ...       ...      ...
# 1239  2823533          Templin      DE  53.12   13.50     48.00       93
# 1240   211647            Lodja      CD  -3.52   23.60     73.35       95
# 1241    69559            Zabid      YE  14.20   44.50     62.94       39
# 1242  3996234  Lazaro Cardenas      MX  28.39 -105.62     46.99       83
# 1243  2036892           Hohhot      CN  40.81  111.65     46.40       24
#
#       Cloudiness  Wind Speed (mph)   Date_Time
# 0             29             14.65  1573883089
# 1             43              3.36  1573883089
# 2             91             17.22  1573883089
# 3             40              5.82  1573883089
# 4             75              9.17  1573883089
# ...          ...               ...         ...
# 1239          75              9.17  1573884608
# 1240         100              2.01  1573884608
# 1241           0              5.06  1573884608
# 1242           2              1.01  1573884608
# 1243          20              2.24  1573884608
#
# [1244 rows x 10 columns]

# %%
cities_df.to_csv("data/cities_in_owm.csv")

# %%
api_call_log_df = pd.DataFrame(api_call_log, columns=["API Call Log"])
api_call_log_df.to_csv("data/api_results.csv", index=False, header=False)
